# %% [markdown]
# ### Búsqueda de documentos por índice inverso

# %% [markdown]
# #### Búsqueda de documentos por palabras

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import  Counter

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer

# %%
import nltk
nltk.download(['punkt','averaged_perceptron_tagger','wordnet'])

from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet
from nltk.corpus.reader.wordnet import NOUN, VERB, ADV, ADJ
# Out:
# [nltk_data] Downloading package punkt to /home/vania/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/vania/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /home/vania/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# Cargamos los datos

# %%
db = fetch_20newsgroups(remove=('headers','footers','quotes'))

# %%
len(db.data)
# Out:
# 11314

# %%
db.data[0]
# Out:
# 'I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.'

# %%
morphy_tag = {
    'JJ' : ADJ,
    'JJR' : ADJ,
    'JJS' : ADJ,
    'VB' : VERB,
    'VBD' : VERB,
    'VBG' : VERB,
    'VBN' : VERB,
    'VBP' : VERB,
    'VBZ' : VERB,
    'RB' : ADV,
    'RBR' : ADV,
    'RBS' : ADV
}

def doc_a_tokens(doc):
    tagged = pos_tag(word_tokenize(doc.lower()))
    print(tagged)
    lemmatizer = WordNetLemmatizer()
    tokens = []
    for p,t in tagged:
        tokens.append(lemmatizer.lemmatize(p, pos=morphy_tag.get(t, NOUN)))

    return tokens

# %% [markdown]
# Guardamos el conjunto preprocesado como una lista de cadenas, una por documento

# %%
corpus = []
for d in db.data[:100]:
    d = d.replace('\n',' ').replace('\r',' ').replace('\t',' ')
    tokens = doc_a_tokens(d)
    corpus.append(' '.join(tokens))
# Out:
# [('i', 'NN'), ('was', 'VBD'), ('wondering', 'VBG'), ('if', 'IN'), ('anyone', 'NN'), ('out', 'IN'), ('there', 'RB'), ('could', 'MD'), ('enlighten', 'VB'), ('me', 'PRP'), ('on', 'IN'), ('this', 'DT'), ('car', 'NN'), ('i', 'NN'), ('saw', 'VBD'), ('the', 'DT'), ('other', 'JJ'), ('day', 'NN'), ('.', '.'), ('it', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('2-door', 'JJ'), ('sports', 'NNS'), ('car', 'NN'), (',', ','), ('looked', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('from', 'IN'), ('the', 'DT'), ('late', 'JJ'), ('60s/', 'CD'), ('early', 'JJ'), ('70s', 'CD'), ('.', '.'), ('it', 'PRP'), ('was', 'VBD'), ('called', 'VBN'), ('a', 'DT'), ('bricklin', 'NN'), ('.', '.'), ('the', 'DT'), ('doors', 'NNS'), ('were', 'VBD'), ('really', 'RB'), ('small', 'JJ'), ('.', '.'), ('in', 'IN'), ('addition', 'NN'), (',', ','), ('the', 'DT'), ('front', 'NN'), ('bumper', 'NN'), ('was', 'VBD'), ('separate', 'JJ'), ('from', 'IN'), ('the', 'DT'), ('rest', 'NN'), ('of', 'IN'), ('the', 'DT'), ('body', 'NN'), ('.', '.'), ('this', 'DT'), ('is', 'VBZ'), ('all', 'DT'), ('i', 'NN'), ('know', 'VBP'), ('.', '.'), ('if', 'IN'), ('anyone', 'NN'), ('can', 'MD'), ('tellme', 'VB'), ('a', 'DT'), ('model', 'NN'), ('name', 'NN'), (',', ','), ('engine', 'NN'), ('specs', 'NN'), (',', ','), ('years', 'NNS'), ('of', 'IN'), ('production', 'NN'), (',', ','), ('where', 'WRB'), ('this', 'DT'), ('car', 'NN'), ('is', 'VBZ'), ('made', 'VBN'), (',', ','), ('history', 'NN'), (',', ','), ('or', 'CC'), ('whatever', 'WDT'), ('info', 'VBP'), ('you', 'PRP'), ('have', 'VBP'), ('on', 'IN'), ('this', 'DT'), ('funky', 'NN'), ('looking', 'VBG'), ('car', 'NN'), (',', ','), ('please', 'VB'), ('e-mail', 'JJ'), ('.', '.')]
# [('a', 'DT'), ('fair', 'JJ'), ('number', 'NN'), ('of', 'IN'), ('brave', 'JJ'), ('souls', 'NNS'), ('who', 'WP'), ('upgraded', 'VBD'), ('their', 'PRP$'), ('si', 'NN'), ('clock', 'NN'), ('oscillator', 'NN'), ('have', 'VBP'), ('shared', 'VBN'), ('their', 'PRP$'), ('experiences', 'NNS'), ('for', 'IN'), ('this', 'DT'), ('poll', 'NN'), ('.', '.'), ('please', 'VB'), ('send', 'VB'), ('a', 'DT'), ('brief', 'JJ'), ('message', 'NN'), ('detailing', 'VBG'), ('your', 'PRP$'), ('experiences', 'NNS'), ('with', 'IN'), ('the', 'DT'), ('procedure', 'NN'), ('.', '.'), ('top', 'JJ'), ('speed', 'NN'), ('attained', 'VBD'), (',', ','), ('cpu', 'NN'), ('rated', 'VBD'), ('speed', 'NN'), (',', ','), ('add', 'VB'), ('on', 'IN'), ('cards', 'NNS'), ('and', 'CC'), ('adapters', 'NNS'), (',', ','), ('heat', 'NN'), ('sinks', 'NNS'), (',', ','), ('hour', 'NN'), ('of', 'IN'), ('usage', 'JJ'), ('per', 'IN'), ('day', 'NN'), (',', ','), ('floppy', 'JJ'), ('disk', 'NN'), ('functionality', 'NN'), ('with', 'IN'), ('800', 'CD'), ('and', 'CC'), ('1.4', 'CD'), ('m', 'NN'), ('floppies', 'NNS'), ('are', 'VBP'), ('especially', 'RB'), ('requested', 'VBN'), ('.', '.'), ('i', 'NN'), ('will', 'MD'), ('be', 'VB'), ('summarizing', 'VBG'), ('in', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('two', 'CD'), ('days', 'NNS'), (',', ','), ('so', 'IN'), ('please', 'JJ'), ('add', 'NN'), ('to', 'TO'), ('the', 'DT'), ('network', 'NN'), ('knowledge', 'NN'), ('base', 'NN'), ('if', 'IN'), ('you', 'PRP'), ('have', 'VBP'), ('done', 'VBN'), ('the', 'DT'), ('clock', 'NN'), ('upgrade', 'NN'), ('and', 'CC'), ('have', 'VBP'), ("n't", 'RB'), ('answered', 'VBN'), ('this', 'DT'), ('poll', 'NN'), ('.', '.'), ('thanks', 'NNS'), ('.', '.')]
# [('well', 'RB'), ('folks', 'NNS'), (',', ','), ('my', 'PRP$'), ('mac', 'JJ'), ('plus', 'CC'), ('finally', 'RB'), ('gave', 'VBD'), ('up', 'RP'), ('the', 'DT'), ('ghost', 'NN'), ('this', 'DT'), ('weekend', 'NN'), ('after', 'IN'), ('starting', 'VBG'), ('life', 'NN'), ('as', 'IN'), ('a', 'DT'), ('512k', 'CD'), ('way', 'NN'), ('back', 'RB'), ('in', 'IN'), ('1985.', 'CD'), ('sooo', 'NN'), (',', ','), ('i', 'JJ'), ("'m", 'VBP'), ('in', 'IN'), ('the', 'DT'), ('market', 'NN'), ('for', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('machine', 'NN'), ('a', 'DT'), ('bit', 'NN'), ('sooner', 'JJR'), ('than', 'IN'), ('i', 'RB'), ('intended', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('...', ':'), ('i', 'JJ'), ("'m", 'VBP'), ('looking', 'VBG'), ('into', 'IN'), ('picking', 'VBG'), ('up', 'RP'), ('a', 'DT'), ('powerbook', 'NN'), ('160', 'CD'), ('or', 'CC'), ('maybe', 'RB'), ('180', 'CD'), ('and', 'CC'), ('have', 'VB'), ('a', 'DT'), ('bunch', 'NN'), ('of', 'IN'), ('questions', 'NNS'), ('that', 'WDT'), ('(', '('), ('hopefully', 'RB'), (')', ')'), ('somebody', 'NN'), ('can', 'MD'), ('answer', 'VB'), (':', ':'), ('*', 'NN'), ('does', 'VBZ'), ('anybody', 'NN'), ('know', 'VB'), ('any', 'DT'), ('dirt', 'NN'), ('on', 'IN'), ('when', 'WRB'), ('the', 'DT'), ('next', 'JJ'), ('round', 'NN'), ('of', 'IN'), ('powerbook', 'NN'), ('introductions', 'NNS'), ('are', 'VBP'), ('expected', 'VBN'), ('?', '.'), ('i', 'JJ'), ("'d", 'MD'), ('heard', 'VB'), ('the', 'DT'), ('185c', 'CD'), ('was', 'VBD'), ('supposed', 'VBN'), ('to', 'TO'), ('make', 'VB'), ('an', 'DT'), ('appearence', 'NN'), ('``', '``'), ('this', 'DT'), ('summer', 'NN'), ("''", "''"), ('but', 'CC'), ('have', 'VBP'), ("n't", 'RB'), ('heard', 'VBN'), ('anymore', 'RB'), ('on', 'IN'), ('it', 'PRP'), ('-', ':'), ('and', 'CC'), ('since', 'IN'), ('i', 'NN'), ('do', 'VBP'), ("n't", 'RB'), ('have', 'VB'), ('access', 'NN'), ('to', 'TO'), ('macleak', 'VB'), (',', ','), ('i', 'NN'), ('was', 'VBD'), ('wondering', 'VBG'), ('if', 'IN'), ('anybody', 'NN'), ('out', 'IN'), ('there', 'RB'), ('had', 'VBD'), ('more', 'JJR'), ('info', 'NNS'), ('...', ':'), ('*', 'NN'), ('has', 'VBZ'), ('anybody', 'VBN'), ('heard', 'JJ'), ('rumors', 'NNS'), ('about', 'IN'), ('price', 'NN'), ('drops', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('powerbook', 'NN'), ('line', 'NN'), ('like', 'IN'), ('the', 'DT'), ('ones', 'NNS'), ('the', 'DT'), ('duo', 'NN'), ("'s", 'POS'), ('just', 'RB'), ('went', 'VBD'), ('through', 'IN'), ('recently', 'RB'), ('?', '.'), ('*', 'VB'), ('what', 'WP'), ("'s", 'VBZ'), ('the', 'DT'), ('impression', 'NN'), ('of', 'IN'), ('the', 'DT'), ('display', 'NN'), ('on', 'IN'), ('the', 'DT'), ('180', 'CD'), ('?', '.'), ('i', 'NN'), ('could', 'MD'), ('probably', 'RB'), ('swing', 'VBG'), ('a', 'DT'), ('180', 'CD'), ('if', 'IN'), ('i', 'JJ'), ('got', 'VBD'), ('the', 'DT'), ('80mb', 'CD'), ('disk', 'NN'), ('rather', 'RB'), ('than', 'IN'), ('the', 'DT'), ('120', 'CD'), (',', ','), ('but', 'CC'), ('i', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('really', 'RB'), ('have', 'VB'), ('a', 'DT'), ('feel', 'NN'), ('for', 'IN'), ('how', 'WRB'), ('much', 'JJ'), ('``', '``'), ('better', 'JJR'), ("''", "''"), ('the', 'DT'), ('display', 'NN'), ('is', 'VBZ'), ('(', '('), ('yea', 'UH'), (',', ','), ('it', 'PRP'), ('looks', 'VBZ'), ('great', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('store', 'NN'), (',', ','), ('but', 'CC'), ('is', 'VBZ'), ('that', 'IN'), ('all', 'DT'), ('``', '``'), ('wow', 'NN'), ("''", "''"), ('or', 'CC'), ('is', 'VBZ'), ('it', 'PRP'), ('really', 'RB'), ('that', 'IN'), ('good', 'JJ'), ('?', '.'), (')', ')'), ('.', '.'), ('could', 'MD'), ('i', 'VB'), ('solicit', 'CC'), ('some', 'DT'), ('opinions', 'NNS'), ('of', 'IN'), ('people', 'NNS'), ('who', 'WP'), ('use', 'VBP'), ('the', 'DT'), ('160', 'CD'), ('and', 'CC'), ('180', 'CD'), ('day-to-day', 'NN'), ('on', 'IN'), ('if', 'IN'), ('its', 'PRP$'), ('worth', 'NN'), ('taking', 'VBG'), ('the', 'DT'), ('disk', 'NN'), ('size', 'NN'), ('and', 'CC'), ('money', 'NN'), ('hit', 'VBN'), ('to', 'TO'), ('get', 'VB'), ('the', 'DT'),  ...
# [('do', 'VBP'), ('you', 'PRP'), ('have', 'VBP'), ('weitek', 'VBN'), ("'s", 'POS'), ('address/phone', 'NN'), ('number', 'NN'), ('?', '.'), ('i', 'JJ'), ("'d", 'MD'), ('like', 'VB'), ('to', 'TO'), ('get', 'VB'), ('some', 'DT'), ('information', 'NN'), ('about', 'IN'), ('this', 'DT'), ('chip', 'NN'), ('.', '.')]
# [('from', 'IN'), ('article', 'NN'), ('<', 'NNP'), ('c5owcb.n3p', 'NN'), ('@', 'NNP'), ('world.std.com', 'NN'), ('>', 'NN'), (',', ','), ('by', 'IN'), ('tombaker', 'NN'), ('@', 'NNP'), ('world.std.com', 'NN'), ('(', '('), ('tom', 'VB'), ('a', 'DT'), ('baker', 'NN'), (')', ')'), (':', ':'), ('my', 'PRP$'), ('understanding', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ("'expected", 'JJ'), ('errors', 'NNS'), ("'", 'POS'), ('are', 'VBP'), ('basically', 'RB'), ('known', 'VBN'), ('bugs', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('warning', 'NN'), ('system', 'NN'), ('software', 'NN'), ('-', ':'), ('things', 'NNS'), ('are', 'VBP'), ('checked', 'VBN'), ('that', 'IN'), ('do', 'VBP'), ("n't", 'RB'), ('have', 'VB'), ('the', 'DT'), ('right', 'JJ'), ('values', 'NNS'), ('in', 'IN'), ('yet', 'RB'), ('because', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ("n't", 'RB'), ('set', 'VBN'), ('till', 'NN'), ('after', 'IN'), ('launch', 'NN'), (',', ','), ('and', 'CC'), ('suchlike', 'NN'), ('.', '.'), ('rather', 'RB'), ('than', 'IN'), ('fix', 'VB'), ('the', 'DT'), ('code', 'NN'), ('and', 'CC'), ('possibly', 'RB'), ('introduce', 'VB'), ('new', 'JJ'), ('bugs', 'NNS'), (',', ','), ('they', 'PRP'), ('just', 'RB'), ('tell', 'VBP'), ('the', 'DT'), ('crew', 'NN'), ("'ok", 'POS'), (',', ','), ('if', 'IN'), ('you', 'PRP'), ('see', 'VBP'), ('a', 'DT'), ('warning', 'NN'), ('no', 'DT'), ('.', '.'), ('213', 'CD'), ('before', 'IN'), ('liftoff', 'NN'), (',', ','), ('ignore', 'VB'), ('it', 'PRP'), ("'", "''"), ('.', '.')]
# [('of', 'IN'), ('course', 'NN'), ('.', '.'), ('the', 'DT'), ('term', 'NN'), ('must', 'MD'), ('be', 'VB'), ('rigidly', 'RB'), ('defined', 'VBN'), ('in', 'IN'), ('any', 'DT'), ('bill', 'NN'), ('.', '.'), ('i', 'JJ'), ('doubt', 'NN'), ('she', 'PRP'), ('uses', 'VBZ'), ('this', 'DT'), ('term', 'NN'), ('for', 'IN'), ('that', 'DT'), ('.', '.'), ('you', 'PRP'), ('are', 'VBP'), ('using', 'VBG'), ('a', 'DT'), ('quote', 'NN'), ('allegedly', 'RB'), ('from', 'IN'), ('her', 'PRP$'), (',', ','), ('can', 'MD'), ('you', 'PRP'), ('back', 'VB'), ('it', 'PRP'), ('up', 'RP'), ('?', '.'), ('i', 'NN'), ('read', 'VBD'), ('the', 'DT'), ('article', 'NN'), ('as', 'IN'), ('presenting', 'VBG'), ('first', 'RB'), ('an', 'DT'), ('argument', 'NN'), ('about', 'IN'), ('weapons', 'NNS'), ('of', 'IN'), ('mass', 'NN'), ('destruction', 'NN'), ('(', '('), ('as', 'IN'), ('commonly', 'RB'), ('understood', 'NN'), (')', ')'), ('and', 'CC'), ('then', 'RB'), ('switching', 'VBG'), ('to', 'TO'), ('other', 'JJ'), ('topics', 'NNS'), ('.', '.'), ('the', 'DT'), ('first', 'JJ'), ('point', 'NN'), ('evidently', 'RB'), ('was', 'VBD'), ('to', 'TO'), ('show', 'VB'), ('that', 'IN'), ('not', 'RB'), ('all', 'DT'), ('weapons', 'NNS'), ('should', 'MD'), ('be', 'VB'), ('allowed', 'VBN'), (',', ','), ('and', 'CC'), ('then', 'RB'), ('the', 'DT'), ('later', 'JJ'), ('analysis', 'NN'), ('was', 'VBD'), (',', ','), ('given', 'VBN'), ('this', 'DT'), ('understanding', 'NN'), (',', ','), ('to', 'TO'), ('consider', 'VB'), ('another', 'DT'), ('class', 'NN'), ('.', '.')]
# [('there', 'EX'), ('were', 'VBD'), ('a', 'DT'), ('few', 'JJ'), ('people', 'NNS'), ('who', 'WP'), ('responded', 'VBD'), ('to', 'TO'), ('my', 'PRP$'), ('request', 'NN'), ('for', 'IN'), ('info', 'NN'), ('on', 'IN'), ('treatment', 'NN'), ('for', 'IN'), ('astrocytomas', 'NN'), ('through', 'IN'), ('email', 'NN'), (',', ','), ('whom', 'WP'), ('i', 'NN'), ('could', 'MD'), ("n't", 'RB'), ('thank', 'VB'), ('directly', 'RB'), ('because', 'IN'), ('of', 'IN'), ('mail-bouncing', 'JJ'), ('probs', 'NN'), ('(', '('), ('sean', 'JJ'), (',', ','), ('debra', 'NN'), (',', ','), ('and', 'CC'), ('sharon', 'NN'), (')', ')'), ('.', '.'), ('so', 'IN'), ('i', 'JJ'), ('thought', 'NN'), ('i', 'NN'), ("'d", 'MD'), ('publicly', 'RB'), ('thank', 'VB'), ('everyone', 'NN'), ('.', '.'), ('thanks', 'NNS'), ('!', '.'), ('(', '('), ('i', 'JJ'), ("'m", 'VBP'), ('sure', 'JJ'), ('glad', 'NN'), ('i', 'NN'), ('accidentally', 'RB'), ('hit', 'VBD'), ('``', '``'), ('rn', 'NN'), ("''", "''"), ('instead', 'RB'), ('of', 'IN'), ('``', '``'), ('rm', 'NN'), ("''", "''"), ('when', 'WRB'), ('i', 'NN'), ('was', 'VBD'), ('trying', 'VBG'), ('to', 'TO'), ('delete', 'VB'), ('a', 'DT'), ('file', 'NN'), ('last', 'JJ'), ('september', 'NN'), ('.', '.'), ('``', '``'), ('hmmm', 'NN'), ('...', ':'), ("'news", 'CC'), ('?', '.'), ("'", "''"), ('what', 'WP'), ("'s", 'VBZ'), ('this', 'DT'), ('?', '.'), ("''", "''"), ('....', 'NN'), (')', ')')]
# [('all', 'DT'), ('this', 'DT'), ('shows', 'NNS'), ('is', 'VBZ'), ('that', 'IN'), ('you', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('much', 'RB'), ('about', 'IN'), ('scsi', 'NN'), ('.', '.'), ('scsi-1', 'JJ'), ('{', '('), ('with', 'IN'), ('a', 'DT'), ('scsi-1', 'JJ'), ('controler', 'NN'), ('chip', 'NN'), ('}', ')'), ('range', 'NN'), ('is', 'VBZ'), ('indeed', 'RB'), ('0-5mb/s', 'JJ'), ('and', 'CC'), ('that', 'DT'), ('is', 'VBZ'), ('all', 'DT'), ('you', 'PRP'), ('have', 'VBP'), ('right', 'JJ'), ('about', 'IN'), ('scsi', 'JJ'), ('scsi-1', 'JJ'), ('{', '('), ('with', 'IN'), ('a', 'DT'), ('scsi-2', 'JJ'), ('controller', 'NN'), ('chip', 'NN'), ('}', ')'), (':', ':'), ('4-6mb/s', 'JJ'), ('with', 'IN'), ('10mb/s', 'CD'), ('burst', 'JJ'), ('{', '('), ('8-bit', 'JJ'), ('}', ')'), ('note', 'VBP'), ('the', 'DT'), ('increase', 'NN'), ('in', 'IN'), ('speed', 'NN'), (',', ','), ('the', 'DT'), ('mac', 'NN'), ('quadra', 'NN'), ('uses', 'VBZ'), ('this', 'DT'), ('version', 'NN'), ('of', 'IN'), ('scsi-1', 'NN'), ('so', 'IN'), ('it', 'PRP'), ('does', 'VBZ'), ('exist', 'VB'), ('.', '.'), ('some', 'DT'), ('pc', 'NN'), ('use', 'NN'), ('this', 'DT'), ('set', 'VBD'), ('up', 'RP'), ('too', 'RB'), ('.', '.'), ('scsi-2', 'JJ'), ('{', '('), ('8-bit/scsi-1', 'JJ'), ('mode', 'NN'), ('}', ')'), (':', ':'), ('4-6mb/s', 'JJ'), ('with', 'IN'), ('10mb/s', 'CD'), ('burst', 'JJ'), ('scsi-2', 'JJ'), ('{', '('), ('16-bit/wide', 'JJ'), ('or', 'CC'), ('fast', 'JJ'), ('mode', 'NN'), ('}', ')'), (':', ':'), ('8-12mb/s', 'JJ'), ('with', 'IN'), ('20mb/s', 'CD'), ('burst', 'JJ'), ('scsi-2', 'JJ'), ('{', '('), ('32-bit/wide', 'JJ'), ('and', 'CC'), ('fast', 'JJ'), ('}', ')'), (':', ':'), ('15-20mb/s', 'JJ'), ('with', 'IN'), ('40mb/s', 'CD'), ('burst', 'NNS'), ('by', 'IN'), ('your', 'PRP$'), ('own', 'JJ'), ('data', 'NN'), ('the', 'DT'), ('``', '``'), ('although', 'IN'), ('scsi', 'NN'), ('is', 'VBZ'), ('twice', 'RB'), ('as', 'RB'), ('fast', 'JJ'), ('as', 'IN'), ('esdi', 'NN'), ("''", "''"), ('is', 'VBZ'), ('correct', 'JJ'), ('with', 'IN'), ('a', 'DT'), ('scsi-2', 'JJ'), ('controller', 'NN'), ('chip', 'NN'), ('scsi-1', 'JJ'), ('can', 'MD'), ('reach', 'VB'), ('10mb/s', 'CD'), ('which', 'WDT'), ('is', 'VBZ'), ('indeed', 'RB'), ('``', '``'), ('20', 'CD'), ('%', 'NN'), ('faster', 'JJR'), ('than', 'IN'), ('ide', 'NN'), ("''", "''"), ('{', '('), ('120', 'CD'), ('%', 'NN'), ('of', 'IN'), ('8.3', 'CD'), ('is', 'VBZ'), ('9.96', 'CD'), ('}', ')'), ('.', '.'), ('all', 'PDT'), ('these', 'DT'), ('scsi', 'JJ'), ('facts', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('posted', 'VBN'), ('to', 'TO'), ('this', 'DT'), ('newsgroup', 'NN'), ('in', 'IN'), ('my', 'PRP$'), ('mac', 'NN'), ('&', 'CC'), ('ibm', 'JJ'), ('info', 'JJ'), ('sheet', 'NN'), ('{', '('), ('available', 'JJ'), ('by', 'IN'), ('ftp', 'NN'), ('on', 'IN'), ('sumex-aim.stanford.edu', 'NN'), ('(', '('), ('36.44.0.6', 'CD'), (')', ')'), ('in', 'IN'), ('the', 'DT'), ('info-mac/report', 'NN'), ('as', 'IN'), ('mac-ibm-compare', 'JJ'), ('[', 'NNP'), ('version', 'NN'), ('#', '#'), (']', 'JJ'), ('.txt', 'NN'), ('(', '('), ('it', 'PRP'), ('should', 'MD'), ('be', 'VB'), ('173', 'CD'), ('but', 'CC'), ('161', 'CD'), ('may', 'MD'), ('still', 'RB'), ('be', 'VB'), ('there', 'RB'), (')', ')'), ('}', ')'), ('part', 'NN'), ('of', 'IN'), ('this', 'DT'), ('problem', 'NN'), ('is', 'VBZ'), ('both', 'DT'), ('mac', 'NN'), ('and', 'CC'), ('ibm', 'JJ'), ('pc', 'NN'), ('are', 'VBP'), ('inconsiant', 'JJ'), ('about', 'IN'), ('what', 'WP'), ('scsi', 'NN'), ('is', 'VBZ'), ('which', 'WDT'), ('.', '.'), ('though', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('well', 'RB'), ('documented', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('quadra', 'NN'), ('has', 'VBZ'), ('a', 'DT'), ('scsi-2', 'JJ'), ('chip', 'NN'), ('an', 'DT'), ('apple', 'NN'), ('salesperson', 'NN'), ('said', 'VBD'), ('``', '``'), ('it', 'PRP'), ('uses', 'VBZ'), ('a', 'DT'), ('fast', 'JJ'), ('scsi-1', 'JJ'), ('chip', 'NN'), ("''", "''"), ('{', '('), ('not', 'RB'), ('at', 'IN'), ('a', 'DT'), ('6mb/s', 'CD'), (' ...
# [('i', 'NNS'), ('have', 'VBP'), ('win', 'VBN'), ('3.0', 'CD'), ('and', 'CC'), ('downloaded', 'VBD'), ('several', 'JJ'), ('icons', 'NNS'), ('and', 'CC'), ('bmp', 'NN'), ("'s", 'POS'), ('but', 'CC'), ('i', 'JJ'), ('ca', 'MD'), ("n't", 'RB'), ('figure', 'VB'), ('out', 'RP'), ('how', 'WRB'), ('to', 'TO'), ('change', 'VB'), ('the', 'DT'), ('``', '``'), ('wallpaper', 'NN'), ("''", "''"), ('or', 'CC'), ('use', 'VB'), ('the', 'DT'), ('icons', 'NNS'), ('.', '.'), ('any', 'DT'), ('help', 'NN'), ('would', 'MD'), ('be', 'VB'), ('appreciated', 'VBN'), ('.', '.'), ('thanx', 'NN'), (',', ','), ('-brando', 'NN')]
# [('i', 'NN'), ("'ve", 'VBP'), ('had', 'VBD'), ('the', 'DT'), ('board', 'NN'), ('for', 'IN'), ('over', 'IN'), ('a', 'DT'), ('year', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('does', 'VBZ'), ('work', 'VB'), ('with', 'IN'), ('diskdoubler', 'NN'), (',', ','), ('but', 'CC'), ('not', 'RB'), ('with', 'IN'), ('autodoubler', 'NN'), (',', ','), ('due', 'JJ'), ('to', 'TO'), ('a', 'DT'), ('licensing', 'NN'), ('problem', 'NN'), ('with', 'IN'), ('stac', 'NN'), ('technologies', 'NNS'), (',', ','), ('the', 'DT'), ('owners', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('board', 'NN'), ("'s", 'POS'), ('compression', 'NN'), ('technology', 'NN'), ('.', '.'), ('(', '('), ('i', 'JJ'), ("'m", 'VBP'), ('writing', 'VBG'), ('this', 'DT'), ('from', 'IN'), ('memory', 'NN'), (';', ':'), ('i', 'CC'), ("'ve", 'VBP'), ('lost', 'VBN'), ('the', 'DT'), ('reference', 'NN'), ('.', '.'), ('please', 'NN'), ('correct', 'VB'), ('me', 'PRP'), ('if', 'IN'), ('i', 'JJ'), ("'m", 'VBP'), ('wrong', 'JJ'), ('.', '.'), (')', ')'), ('using', 'VBG'), ('the', 'DT'), ('board', 'NN'), (',', ','), ('i', 'VB'), ("'ve", 'VBP'), ('had', 'VBN'), ('problems', 'NNS'), ('with', 'IN'), ('file', 'JJ'), ('icons', 'NNS'), ('being', 'VBG'), ('lost', 'VBN'), (',', ','), ('but', 'CC'), ('it', 'PRP'), ("'s", 'VBZ'), ('hard', 'JJ'), ('to', 'TO'), ('say', 'VB'), ('whether', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('board', 'NN'), ("'s", 'POS'), ('fault', 'NN'), ('or', 'CC'), ('something', 'NN'), ('else', 'RB'), (';', ':'), ('however', 'RB'), (',', ','), ('if', 'IN'), ('i', 'JJ'), ('decompress', 'VBP'), ('the', 'DT'), ('troubled', 'JJ'), ('file', 'NN'), ('and', 'CC'), ('recompress', 'NN'), ('it', 'PRP'), ('without', 'IN'), ('the', 'DT'), ('board', 'NN'), (',', ','), ('the', 'DT'), ('icon', 'NN'), ('usually', 'RB'), ('reappears', 'VBZ'), ('.', '.'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('above', 'NN'), ('mentioned', 'VBD'), ('licensing', 'NN'), ('problem', 'NN'), (',', ','), ('the', 'DT'), ('freeware', 'NN'), ('expansion', 'NN'), ('utility', 'NN'), ('dd', 'NN'), ('expand', 'NN'), ('will', 'MD'), ('not', 'RB'), ('decompress', 'VB'), ('a', 'DT'), ('board-compressed', 'JJ'), ('file', 'NN'), ('unless', 'IN'), ('you', 'PRP'), ('have', 'VBP'), ('the', 'DT'), ('board', 'NN'), ('installed', 'VBD'), ('.', '.'), ('since', 'IN'), ('stac', 'NN'), ('has', 'VBZ'), ('its', 'PRP$'), ('own', 'JJ'), ('product', 'NN'), ('now', 'RB'), (',', ','), ('it', 'PRP'), ('seems', 'VBZ'), ('unlikely', 'JJ'), ('that', 'IN'), ('the', 'DT'), ('holes', 'NNS'), ('in', 'IN'), ('autodoubler/diskdoubler', 'NN'), ('related', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('board', 'NN'), ('will', 'MD'), ('be', 'VB'), ('fixed', 'VBN'), ('.', '.'), ('which', 'WDT'), ('is', 'VBZ'), ('sad', 'JJ'), (',', ','), ('and', 'CC'), ('makes', 'VBZ'), ('me', 'PRP'), ('very', 'RB'), ('reluctant', 'JJ'), ('to', 'TO'), ('buy', 'VB'), ('stac', 'NN'), ("'s", 'POS'), ('product', 'NN'), ('since', 'IN'), ('they', 'PRP'), ("'re", 'VBP'), ('being', 'VBG'), ('so', 'RB'), ('stinky', 'RB'), ('.', '.'), ('(', '('), ('but', 'CC'), ('hey', 'NN'), (',', ','), ('that', 'WDT'), ("'s", 'VBZ'), ('competition', 'NN'), ('.', '.'), (')', ')'), ('--', ':')]
# [('i', 'NNS'), ('have', 'VBP'), ('a', 'DT'), ('line', 'NN'), ('on', 'IN'), ('a', 'DT'), ('ducati', 'NN'), ('900gts', 'CD'), ('1978', 'CD'), ('model', 'NN'), ('with', 'IN'), ('17k', 'CD'), ('on', 'IN'), ('the', 'DT'), ('clock', 'NN'), ('.', '.'), ('runs', 'VBZ'), ('very', 'RB'), ('well', 'RB'), (',', ','), ('paint', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('bronze/brown/orange', 'NN'), ('faded', 'VBD'), ('out', 'RP'), (',', ','), ('leaks', 'VBZ'), ('a', 'DT'), ('bit', 'NN'), ('of', 'IN'), ('oil', 'NN'), ('and', 'CC'), ('pops', 'VBZ'), ('out', 'IN'), ('of', 'IN'), ('1st', 'CD'), ('with', 'IN'), ('hard', 'JJ'), ('accel', 'NN'), ('.', '.'), ('the', 'DT'), ('shop', 'NN'), ('will', 'MD'), ('fix', 'VB'), ('trans', 'NNS'), ('and', 'CC'), ('oil', 'NN'), ('leak', 'NN'), ('.', '.'), ('they', 'PRP'), ('sold', 'VBD'), ('the', 'DT'), ('bike', 'NN'), ('to', 'TO'), ('the', 'DT'), ('1', 'CD'), ('and', 'CC'), ('only', 'RB'), ('owner', 'NN'), ('.', '.'), ('they', 'PRP'), ('want', 'VBP'), ('$', '$'), ('3495', 'CD'), (',', ','), ('and', 'CC'), ('i', 'VB'), ('am', 'VBP'), ('thinking', 'VBG'), ('more', 'JJR'), ('like', 'IN'), ('$', '$'), ('3k', 'CD'), ('.', '.'), ('any', 'DT'), ('opinions', 'NNS'), ('out', 'IN'), ('there', 'RB'), ('?', '.'), ('please', 'NN'), ('email', 'VB'), ('me', 'PRP'), ('.', '.'), ('thanks', 'NNS'), ('.', '.'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('a', 'DT'), ('nice', 'JJ'), ('stable', 'JJ'), ('mate', 'NN'), ('to', 'TO'), ('the', 'DT'), ('beemer', 'NN'), ('.', '.'), ('then', 'RB'), ('i', 'VBZ'), ("'ll", 'MD'), ('get', 'VB'), ('a', 'DT'), ('jap', 'NN'), ('bike', 'NN'), ('and', 'CC'), ('call', 'VB'), ('myself', 'PRP'), ('axis', 'JJ'), ('motors', 'NNS'), ('!', '.'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('-', ':'), ('``', '``'), ('tuba', 'NN'), ("''", "''"), ('(', '('), ('irwin', 'VB'), (')', ')'), ('``', '``'), ('i', 'JJ'), ('honk', 'NN'), ('therefore', 'NN'), ('i', 'NN'), ('am', 'VBP'), ("''", "''"), ('computrac-richardson', 'NN'), (',', ','), ('tx', 'NN'), ('irwin', 'NN'), ('@', 'NNP'), ('cmptrc.lonestar.org', 'NN'), ('dod', 'NN'), ('#', '#'), ('0826', 'CD'), ('(', '('), ('r75/6', 'NN'), (')', ')')]
# [('yep', 'NN'), (',', ','), ('that', 'WDT'), ("'s", 'VBZ'), ('pretty', 'RB'), ('much', 'JJ'), ('it', 'PRP'), ('.', '.'), ('i', 'VB'), ("'m", 'VBP'), ('not', 'RB'), ('a', 'DT'), ('jew', 'NN'), ('but', 'CC'), ('i', 'JJ'), ('understand', 'VBP'), ('that', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('the', 'DT'), ('jewish', 'JJ'), ('way', 'NN'), ('of', 'IN'), ('thinking', 'NN'), ('.', '.'), ('however', 'RB'), (',', ','), ('the', 'DT'), ('jews', 'NNS'), ('believe', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('covenant', 'NN'), ('between', 'IN'), ('yhwh', 'NN'), ('and', 'CC'), ('the', 'DT'), ('patriarchs', 'NN'), ('(', '('), ('abraham', 'JJ'), ('and', 'CC'), ('moses', 'NNS'), (',', ','), ('in', 'IN'), ('this', 'DT'), ('case', 'NN'), (')', ')'), ('establishes', 'VBZ'), ('a', 'DT'), ('moral', 'JJ'), ('code', 'NN'), ('to', 'TO'), ('follow', 'VB'), ('for', 'IN'), ('mankind', 'NN'), ('.', '.'), ('even', 'RB'), ('the', 'DT'), ('jews', 'NNS'), ('could', 'MD'), ('not', 'RB'), ('decide', 'VB'), ('where', 'WRB'), ('the', 'DT'), ('boundaries', 'NNS'), ('fall', 'NN'), (',', ','), ('though', 'RB'), ('.', '.'), ('as', 'IN'), ('i', 'JJ'), ('understand', 'VBP'), ('it', 'PRP'), (',', ','), ('the', 'DT'), ('sadducees', 'NNS'), ('believed', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('torah', 'NN'), ('was', 'VBD'), ('all', 'DT'), ('that', 'DT'), ('was', 'VBD'), ('required', 'VBN'), (',', ','), ('whereas', 'IN'), ('the', 'DT'), ('pharisees', 'NNS'), ('(', '('), ('the', 'DT'), ('ancestors', 'NNS'), ('of', 'IN'), ('modern', 'JJ'), ('judaism', 'NN'), (')', ')'), ('believed', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('torah', 'NN'), ('was', 'VBD'), ('available', 'JJ'), ('for', 'IN'), ('interpretation', 'NN'), ('to', 'TO'), ('lead', 'VB'), ('to', 'TO'), ('an', 'DT'), ('understanding', 'NN'), ('of', 'IN'), ('the', 'DT'), ('required', 'JJ'), ('morality', 'NN'), ('in', 'IN'), ('all', 'DT'), ('its', 'PRP$'), ('nuances', 'NNS'), ('(', '('), ('-', ':'), ('>', 'NN'), ('talmud', 'NN'), (')', ')'), ('.', '.'), ('the', 'DT'), ('essence', 'NN'), ('of', 'IN'), ('all', 'DT'), ('of', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('that', 'DT'), ('biblical', 'JJ'), ('morality', 'NN'), ('is', 'VBZ'), ('an', 'DT'), ('interface', 'NN'), ('between', 'IN'), ('man', 'NN'), ('and', 'CC'), ('yhwh', 'NN'), ('(', '('), ('for', 'IN'), ('a', 'DT'), ('jew', 'NN'), ('or', 'CC'), ('christian', 'NN'), (')', ')'), ('and', 'CC'), ('does', 'VBZ'), ('not', 'RB'), ('necessarily', 'RB'), ('indicate', 'VB'), ('anything', 'NN'), ('about', 'IN'), ('yhwh', 'JJ'), ('outside', 'NN'), ('of', 'IN'), ('that', 'DT'), ('relationship', 'NN'), ('(', '('), ('although', 'IN'), ('one', 'CD'), ('can', 'MD'), ('speculate', 'VB'), (')', ')'), ('.', '.'), ('the', 'DT'), ('trouble', 'NN'), ('with', 'IN'), ('all', 'DT'), ('of', 'IN'), ('this', 'DT'), ('is', 'VBZ'), ('that', 'IN'), ('we', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('really', 'RB'), ('know', 'VB'), ('what', 'WP'), ('the', 'DT'), ('``', '``'), ('created', 'VBN'), ('in', 'IN'), ('his', 'PRP$'), ('image', 'NN'), ("''", "''"), ('means', 'VBZ'), ('.', '.'), ('i', 'VB'), ("'ve", 'VBP'), ('heard', 'VBN'), ('a', 'DT'), ('number', 'NN'), ('of', 'IN'), ('different', 'JJ'), ('opinions', 'NNS'), ('on', 'IN'), ('this', 'DT'), ('and', 'CC'), ('have', 'VBP'), ('still', 'RB'), ('not', 'RB'), ('come', 'VBN'), ('to', 'TO'), ('any', 'DT'), ('conclusion', 'NN'), ('.', '.'), ('this', 'DT'), ('rather', 'RB'), ('upsets', 'VBZ'), ('the', 'DT'), ('apple', 'NN'), ('cart', 'NN'), ('if', 'IN'), ('one', 'CD'), ('wants', 'VBZ'), ('to', 'TO'), ('base', 'VB'), ('a', 'DT'), ('life', 'NN'), ('script', 'NN'), ('on', 'IN'), ('this', 'DT'), ('shaky', 'JJ'), ('foundation', 'NN'), ('(', '('), ('to', 'TO'), ('mix', 'VB'), ('metaphors', 'NNS'), ('unashamedly', 'RB'), ('!', '.'), (')', ')'), ('as', 'IN'), ('to', 'TO'), ('living', 'VBG'), ('by', 'IN'), ('christ', 'NN'), ("'s", 'POS'), ('example', 'NN'), (',', ','), ('we', 'PRP'), ('know', 'VBP'), ('very', 'RB'), ('little', 'JJ'), ('about', 'RB'), ('jesus', 'NN'), ('as',  ...
# [('--', ':')]
# [('{', '('), ('description', 'NN'), ('of', 'IN'), ('``', '``'), ('external', 'JJ'), ('tank', 'NN'), ("''", "''"), ('option', 'NN'), ('for', 'IN'), ('ssf', 'JJ'), ('redesign', 'NN'), ('deleted', 'VBD'), ('}', ')'), ('yo', 'JJR'), ('ken', 'NNS'), (',', ','), ('let', 'VB'), ("'s", 'POS'), ('keep', 'VB'), ('on-top', 'NN'), ('of', 'IN'), ('things', 'NNS'), ('!', '.'), ('both', 'DT'), ('the', 'DT'), ('``', '``'), ('external', 'JJ'), ('tank', 'NN'), ("''", "''"), ('and', 'CC'), ('``', '``'), ('wingless', 'JJ'), ('orbiter', 'NN'), ("''", "''"), ('options', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('deleted', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('ssf', 'NN'), ('redesign', 'NN'), ('options', 'NNS'), ('list', 'NN'), ('.', '.'), ('today', 'NN'), ("'s", 'POS'), ('(', '('), ('4/23', 'CD'), (')', ')'), ('edition', 'NN'), ('of', 'IN'), ('the', 'DT'), ('new', 'JJ'), ('york', 'NN'), ('times', 'NNS'), ('reports', 'VBP'), ('that', 'IN'), ("o'connor", 'NN'), ('told', 'VBD'), ('the', 'DT'), ('panel', 'NN'), ('that', 'IN'), ('some', 'DT'), ('redesign', 'NN'), ('proposals', 'NNS'), ('have', 'VBP'), ('been', 'VBN'), ('dropped', 'VBN'), (',', ','), ('such', 'JJ'), ('as', 'IN'), ('using', 'VBG'), ('the', 'DT'), ('``', '``'), ('giant', 'JJ'), ('external', 'JJ'), ('fuel', 'NN'), ('tanks', 'NNS'), ('used', 'VBN'), ('in', 'IN'), ('launching', 'VBG'), ('space', 'NN'), ('shuttles', 'NNS'), (',', ','), ("''", "''"), ('and', 'CC'), ('building', 'VBG'), ('a', 'DT'), ('``', '``'), ('station', 'NN'), ('around', 'IN'), ('an', 'DT'), ('existing', 'VBG'), ('space', 'NN'), ('shuttle', 'NN'), ('with', 'IN'), ('its', 'PRP$'), ('wings', 'NNS'), ('and', 'CC'), ('tail', 'NN'), ('removed', 'VBN'), ('.', '.'), ("''", "''"), ('currently', 'RB'), (',', ','), ('there', 'EX'), ('are', 'VBP'), ('three', 'CD'), ('options', 'NNS'), ('being', 'VBG'), ('considered', 'VBN'), (',', ','), ('as', 'IN'), ('presented', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('advisory', 'JJ'), ('panel', 'NN'), ('meeting', 'NN'), ('yesterday', 'NN'), ('(', '('), ('and', 'CC'), ('as', 'RB'), ('reported', 'VBN'), ('in', 'IN'), ('today', 'NN'), ("'s", 'POS'), ('times', 'NNS'), (')', ')'), ('.', '.'), ('option', 'NN'), ('``', '``'), ('a', 'DT'), ("''", "''"), ('-', ':'), ('low', 'JJ'), ('cost', 'NN'), ('modular', 'JJ'), ('approach', 'NN'), ('this', 'DT'), ('option', 'NN'), ('is', 'VBZ'), ('being', 'VBG'), ('studied', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('team', 'NN'), ('from', 'IN'), ('msfc', 'NN'), ('.', '.'), ('{', '('), ('as', 'IN'), ('an', 'DT'), ('aside', 'NN'), (',', ','), ('there', 'EX'), ('are', 'VBP'), ('ssf', 'JJ'), ('redesign', 'JJ'), ('teams', 'NNS'), ('at', 'IN'), ('msfc', 'NN'), (',', ','), ('jsc', 'NN'), (',', ','), ('and', 'CC'), ('larc', 'VBZ'), ('supporting', 'VBG'), ('the', 'DT'), ('srt', 'NN'), ('(', '('), ('station', 'NN'), ('redesign', 'NN'), ('team', 'NN'), (')', ')'), ('in', 'IN'), ('crystal', 'JJ'), ('city', 'NN'), ('.', '.'), ('both', 'DT'), ('lerc', 'JJ'), ('and', 'CC'), ('reston', 'JJ'), ('folks', 'NNS'), ('are', 'VBP'), ('also', 'RB'), ('on-site', 'JJ'), ('at', 'IN'), ('these', 'DT'), ('locations', 'NNS'), (',', ','), ('helping', 'VBG'), ('the', 'DT'), ('respective', 'JJ'), ('teams', 'NNS'), ('with', 'IN'), ('their', 'PRP$'), ('redesign', 'NN'), ('activities', 'NNS'), ('.', '.'), ('}', ')'), ('key', 'JJ'), ('features', 'NNS'), ('of', 'IN'), ('this', 'DT'), ('option', 'NN'), ('are', 'VBP'), (':', ':'), ('-', ':'), ('uses', 'VBZ'), ('``', '``'), ('bus-1', 'JJ'), ("''", "''"), (',', ','), ('a', 'DT'), ('modular', 'JJ'), ('bus', 'NN'), ('developed', 'VBN'), ('by', 'IN'), ('lockheed', 'NN'), ('that', 'WDT'), ("'s", 'VBZ'), ('qualified', 'VBN'), ('for', 'IN'), ('sts', 'NNS'), ('and', 'CC'), ('elv', 'NN'), ("'s", 'POS'), ('.', '.'), ('the', 'DT'), ('bus', 'NN'), ('provides', 'VBZ'), ('propulsion', 'NN'), (',', ','), ('gn', 'NN'), ('&', 'CC'), ('c', 'NN'), ('communications', 'NNS'), (',', ','), ('&', 'CC'), ('data', 'NNS'), ('management', 'NN'), ('.', '.'), ('lockheed', 'VB'), ('developed' ...
# [('reduced', 'VBN'), ('prices', 'NNS'), ('!', '.'), ('i', 'NN'), ('have', 'VBP'), ('a', 'DT'), ('list', 'NN'), ('of', 'IN'), ('things', 'NNS'), ('forsale', 'JJ'), ('on', 'IN'), ('behalf', 'NN'), ('of', 'IN'), ('my', 'PRP$'), ('brother', 'NN'), (',', ','), ('who', 'WP'), ("'s", 'VBZ'), ('moving', 'VBG'), ('(', '('), ('moved', 'VBN'), ('already', 'RB'), (')', ')'), ('offer', 'NN'), (':', ':'), ('1', 'CD'), (')', ')'), ('black', 'JJ'), ('and', 'CC'), ('decker', 'NN'), ('duster', 'NN'), ('plus', 'CC'), ('(', '('), ('portable', 'JJ'), ('hand', 'NN'), ('vaccum', 'NN'), (')', ')'), ('purchased', 'VBD'), ('for', 'IN'), ('$', '$'), ('32', 'CD'), (',', ','), ('$', '$'), ('12', 'CD'), ('2', 'CD'), (')', ')'), ('sr-1000', 'NN'), ('dual', 'JJ'), ('cassette', 'NN'), ('portable', 'JJ'), ('player', 'NN'), (',', ','), ('am/fm', 'JJ'), ('5-band', 'CD'), ('graphics', 'NNS'), ('equalizer', 'NN'), (',', ','), ('high', 'JJ'), ('speed', 'NN'), ('dubing', 'NN'), (',', ','), ('duo', 'NN'), ('tape.tape', 'NN'), ('deck', 'VB'), ('a', 'DT'), (',', ','), ('seems', 'VBZ'), ('to', 'TO'), ('have', 'VB'), ('lost', 'VBN'), ('treble', 'JJ'), ('sound', 'NN'), ('.', '.'), ('but', 'CC'), (',', ','), ('i', 'JJ'), ('bet', 'VBD'), ('it', 'PRP'), ("'s", 'VBZ'), ('fixable', 'JJ'), ('.', '.'), ('purchased', 'VBN'), ('for', 'IN'), ('$', '$'), ('80', 'CD'), ('$', '$'), ('25', 'CD'), ('3', 'CD'), (')', ')'), ('monolux', 'NN'), ('zoom', 'NN'), ('microscope', 'NN'), (',', ','), ('up', 'RB'), ('to', 'TO'), ('1200x', 'CD'), ('magnification', 'NN'), ('made', 'VBN'), ('in', 'IN'), ('japan', 'NN'), (',', ','), ('includes', 'VBZ'), ('case', 'NN'), ('and', 'CC'), ('accessories', 'NNS'), ('purchased', 'VBN'), ('for', 'IN'), ('$', '$'), ('50', 'CD'), ('$', '$'), ('20', 'CD'), ('4', 'CD'), (')', ')'), ('sunbeam', 'NN'), ('1400', 'CD'), ('hair', 'NN'), ('dryer', 'NN'), (',', ','), ('the', 'DT'), ('dryer', 'NN'), ('you', 'PRP'), ('put', 'VBP'), ('your', 'PRP$'), ('head', 'NN'), ('under/into', 'NN'), ('.', '.'), ('you', 'PRP'), ('know', 'VBP'), (',', ','), ('the', 'DT'), ('ones', 'NNS'), ('you', 'PRP'), ('see', 'VBP'), ('in', 'IN'), ('the', 'DT'), ('salons', 'NNS'), ('.', '.'), ('(', '('), ('do', 'VBP'), ("n't", 'RB'), ('ask', 'VB'), ('me', 'PRP'), ('why', 'WRB'), ('my', 'PRP$'), ('bro', 'NN'), ('had', 'VBD'), ('it', 'PRP'), (')', ')'), ('purchased', 'VBD'), ('for', 'IN'), ('$', '$'), ('60', 'CD'), ('$', '$'), ('24', 'CD'), ('5', 'CD'), (')', ')'), ('everylast', 'FW'), ('speed', 'NN'), ('bag', 'NN'), (',', ','), ('all', 'DT'), ('leather', 'NN'), ('.', '.'), ('brand', 'NN'), ('new', 'JJ'), (',', ','), ('never', 'RB'), ('used', 'VBD'), ('$', '$'), ('10', 'CD'), ('6', 'CD'), (')', ')'), ('osterizer', 'NN'), ('pusle', 'JJ'), ('matic', 'JJ'), ('blender', 'NN'), (',', ','), ('with', 'IN'), ('10', 'CD'), ('speeds', 'NNS'), ('and', 'CC'), ('a', 'DT'), ('cookbook', 'NN'), (',', ','), ('5', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('$', '$'), ('10', 'CD'), ('purchased', 'VBN'), ('for', 'IN'), ('$', '$'), ('50', 'CD'), ('8', 'CD'), (')', ')'), ('binolux', 'NN'), ('binoculars', 'NNS'), ('.', '.'), ('7x35', 'CD'), (',', ','), ('extra', 'JJ'), ('wide', 'JJ'), ('angle', 'NN'), ('525ft', 'CD'), ('.', '.'), ('at', 'IN'), ('1000yds', 'CD'), ('.', '.'), ('with', 'IN'), ('case', 'NN'), ('.', '.'), ('very', 'RB'), ('new', 'JJ'), ('.', '.'), ('$', '$'), ('20', 'CD'), ('9', 'CD'), (')', ')'), ('proctor', 'NN'), ('and', 'CC'), ('silex', 'JJ'), ('spray', 'NN'), (',', ','), ('steam', 'NN'), ('and', 'CC'), ('dry', 'JJ'), ('iron', 'NN'), ('.', '.'), ('very', 'RB'), ('new', 'JJ'), ('.', '.'), ('$', '$'), ('10', 'CD'), ('any', 'DT'), ('questions', 'NNS'), (',', ','), ('contact', 'VB'), ('me', 'PRP'), ('thru', 'JJ'), ('e-mail', 'JJ'), ('and', 'CC'), ('i', 'NN'), ('will', 'MD'), ('reply', 'VB'), ('expeditously', 'RB'), ('and', 'CC'), ('always', 'RB'), (',', ','), ('s+h', 'NNS'), ('are', 'VBP'), ('not', 'RB'), ('included', 'VBN'), (',', ','), ('so', 'IN'), ('please', 'JJ'), ('consider', 'VB'), ('this', 'DT'), ('.', '.'), ...
# [('do', 'VBP'), ("n't", 'RB'), ('be', 'VB'), ('so', 'RB'), ('sure', 'JJ'), ('.', '.'), ('look', 'VB'), ('what', 'WP'), ('happened', 'VBD'), ('to', 'TO'), ('japanese', 'JJ'), ('citizens', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('us', 'PRP'), ('during', 'IN'), ('world', 'NN'), ('war', 'NN'), ('ii', 'NN'), ('.', '.'), ('if', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('prepared', 'JJ'), ('to', 'TO'), ('say', 'VB'), ('``', '``'), ('let', 'VB'), ("'s", 'POS'), ('round', 'VB'), ('these', 'DT'), ('people', 'NNS'), ('up', 'RB'), ('and', 'CC'), ('stick', 'VB'), ('them', 'PRP'), ('in', 'IN'), ('a', 'DT'), ('concentration', 'NN'), ('camp', 'NN'), ('without', 'IN'), ('trial', 'NN'), ("''", "''"), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('only', 'RB'), ('a', 'DT'), ('short', 'JJ'), ('step', 'NN'), ('to', 'TO'), ('gassing', 'VBG'), ('them', 'PRP'), ('without', 'IN'), ('trial', 'NN'), ('.', '.'), ('after', 'IN'), ('all', 'DT'), (',', ','), ('it', 'PRP'), ('seems', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('nazis', 'NN'), ('originally', 'RB'), ('only', 'RB'), ('intended', 'VBN'), ('to', 'TO'), ('imprison', 'VB'), ('the', 'DT'), ('jews', 'NN'), (';', ':'), ('the', 'DT'), ('final', 'JJ'), ('solution', 'NN'), ('was', 'VBD'), ('dreamt', 'VBN'), ('up', 'RP'), ('partly', 'RB'), ('because', 'IN'), ('they', 'PRP'), ('could', 'MD'), ("n't", 'RB'), ('afford', 'VB'), ('to', 'TO'), ('run', 'VB'), ('the', 'DT'), ('camps', 'NNS'), ('because', 'IN'), ('of', 'IN'), ('the', 'DT'), ('devastation', 'NN'), ('caused', 'VBN'), ('by', 'IN'), ('goering', 'VBG'), ("'s", 'POS'), ('total', 'JJ'), ('war', 'NN'), ('.', '.'), ('those', 'DT'), ('who', 'WP'), ('were', 'VBD'), ("n't", 'RB'), ('gassed', 'VBN'), ('generally', 'RB'), ('died', 'VBN'), ('of', 'IN'), ('malnutrition', 'NN'), ('or', 'CC'), ('disease', 'NN'), ('.', '.')]
# [('i', 'NN'), ('certainly', 'RB'), ('do', 'VBP'), ('use', 'VB'), ('it', 'PRP'), ('whenever', 'WRB'), ('i', 'RB'), ('have', 'VBP'), ('to', 'TO'), ('do', 'VB'), ('tiff', 'NN'), (',', ','), ('and', 'CC'), ('it', 'PRP'), ('usually', 'RB'), ('works', 'VBZ'), ('very', 'RB'), ('well', 'RB'), ('.', '.'), ('that', 'DT'), ("'s", 'VBZ'), ('not', 'RB'), ('my', 'PRP$'), ('point', 'NN'), ('.', '.'), ('i', 'JJ'), ("'m", 'VBP'), ('>', 'JJ'), ('philosophically', 'RB'), ('<', 'VBP'), ('opposed', 'VBN'), ('to', 'TO'), ('it', 'PRP'), ('because', 'IN'), ('of', 'IN'), ('its', 'PRP$'), ('complexity', 'NN'), ('.', '.'), ('this', 'DT'), ('complexity', 'NN'), ('has', 'VBZ'), ('led', 'VBN'), ('to', 'TO'), ('some', 'DT'), ('programs', 'NNS'), ("'", 'POS'), ('poor', 'JJ'), ('tiff', 'NN'), ('writers', 'NNS'), ('making', 'VBG'), ('some', 'DT'), ('very', 'RB'), ('bizarre', 'JJ'), ('files', 'NNS'), (',', ','), ('other', 'JJ'), ('programs', 'NNS'), ("'", 'POS'), ('inability', 'NN'), ('to', 'TO'), ('load', 'VB'), ('tiff', 'NN'), ('images', 'NNS'), ('(', '('), ('though', 'IN'), ('they', 'PRP'), ("'ll", 'MD'), ('save', 'VB'), ('them', 'PRP'), (',', ','), ('of', 'IN'), ('course', 'NN'), (')', ')'), (',', ','), ('and', 'CC'), ('a', 'DT'), ('general', 'JJ'), ('inability', 'NN'), ('to', 'TO'), ('interchange', 'VB'), ('images', 'NNS'), ('between', 'IN'), ('different', 'JJ'), ('environments', 'NNS'), ('despite', 'IN'), ('the', 'DT'), ('fact', 'NN'), ('they', 'PRP'), ('all', 'DT'), ('think', 'VBP'), ('they', 'PRP'), ('understand', 'VBP'), ('tiff', 'NN'), ('.', '.'), ('as', 'IN'), ('the', 'DT'), ('saying', 'NN'), ('goes', 'VBZ'), (',', ','), ('``', '``'), ('it', 'PRP'), ("'s", 'VBZ'), ('not', 'RB'), ('me', 'PRP'), ('i', 'VBP'), ("'m", 'VBP'), ('worried', 'JJ'), ('about-', 'NN'), ('it', 'PRP'), ("'s", 'VBZ'), ('all', 'PDT'), ('the', 'DT'), ('abuse', 'NN'), ('of', 'IN'), ('tiff', 'NN'), ('over', 'IN'), ('the', 'DT'), ('years', 'NNS'), (',', ','), ('and', 'CC'), ('i', 'JJ'), ('chalk', 'VBP'), ('it', 'PRP'), ('all', 'DT'), ('up', 'RB'), ('to', 'TO'), ('the', 'DT'), ('immense', 'NN'), ('(', '('), ('and', 'CC'), ('unnecessary', 'JJ'), (')', ')'), ('complexity', 'NN'), ('of', 'IN'), ('the', 'DT'), ('format', 'NN'), ('.', '.'), ('in', 'IN'), ('the', 'DT'), ('words', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('tiff', 'NN'), ('5.0', 'CD'), ('spec', 'NN'), (',', ','), ('appendix', 'JJ'), ('g', 'NN'), (',', ','), ('page', 'VB'), ('g-1', 'JJ'), ('(', '('), ('capitalized', 'JJ'), ('emphasis', 'NN'), ('mine', 'NN'), (')', ')'), (':', ':'), ('``', '``'), ('the', 'DT'), ('only', 'JJ'), ('problem', 'NN'), ('with', 'IN'), ('this', 'DT'), ('sort', 'NN'), ('of', 'IN'), ('success', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('tiff', 'NN'), ('was', 'VBD'), ('designed', 'VBN'), ('to', 'TO'), ('be', 'VB'), ('powerful', 'JJ'), ('and', 'CC'), ('flexible', 'JJ'), (',', ','), ('at', 'IN'), ('the', 'DT'), ('expense', 'NN'), ('of', 'IN'), ('simplicity', 'NN'), ('.', '.'), ('it', 'PRP'), ('takes', 'VBZ'), ('a', 'DT'), ('fair', 'JJ'), ('amount', 'NN'), ('of', 'IN'), ('effort', 'NN'), ('to', 'TO'), ('handle', 'VB'), ('all', 'PDT'), ('the', 'DT'), ('options', 'NNS'), ('currently', 'RB'), ('defined', 'VBN'), ('in', 'IN'), ('this', 'DT'), ('specification', 'NN'), ('(', '('), ('probably', 'RB'), ('no', 'DT'), ('application', 'NN'), ('does', 'VBZ'), ('a', 'DT'), ('complete', 'JJ'), ('job', 'NN'), (')', ')'), (',', ','), ('and', 'CC'), ('that', 'DT'), ('is', 'VBZ'), ('currently', 'RB'), ('the', 'DT'), ('only', 'JJ'), ('way', 'NN'), ('you', 'PRP'), ('can', 'MD'), ('be', 'VB'), ('>', 'JJ'), ('sure', 'JJ'), ('<', 'NN'), ('that', 'IN'), ('you', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('import', 'VB'), ('any', 'DT'), ('tiff', 'JJ'), ('image', 'NN'), (',', ','), ('since', 'IN'), ('there', 'EX'), ('are', 'VBP'), ('so', 'RB'), ('many', 'JJ'), ('image-generating', 'JJ'), ('applications', 'NNS'), ('out', 'IN'), ('there', 'RB'), ('now', 'RB'), ('.', '.'), ("''", "''"), ('if', 'IN'), ('a', 'DT'), ('progr ...
# [('i', 'NN'), ('recently', 'RB'), ('posted', 'VBD'), ('an', 'DT'), ('article', 'NN'), ('asking', 'VBG'), ('what', 'WP'), ('kind', 'NN'), ('of', 'IN'), ('rates', 'NNS'), ('single', 'JJ'), (',', ','), ('male', 'JJ'), ('drivers', 'NNS'), ('under', 'IN'), ('25', 'CD'), ('yrs', 'NNS'), ('old', 'JJ'), ('were', 'VBD'), ('paying', 'VBG'), ('on', 'IN'), ('performance', 'NN'), ('cars', 'NNS'), ('.', '.'), ('here', 'RB'), ("'s", 'VBZ'), ('a', 'DT'), ('summary', 'NN'), ('of', 'IN'), ('the', 'DT'), ('replies', 'NNS'), ('i', 'VBP'), ('received', 'VBN'), ('.', '.'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('--', ':'), ('-', ':'), ('i', 'NN'), ("'m", 'VBP'), ('not', 'RB'), ('under', 'IN'), ('25', 'CD'), ('anymore', 'NN'), ('(', '('), ('but', 'CC'), ('is', 'VBZ'), ('27', 'CD'), ('close', 'RB'), ('enough', 'RB'), (')', ')'), ('.', '.'), ('1992', 'CD'), ('dodge', 'NN'), ('stealth', 'NN'), ('rt/twin', 'NN'), ('turbo', 'NN'), ('(', '('), ('300hp', 'CD'), ('model', 'NN'), (')', ')'), ('.', '.'), ('no', 'DT'), ('tickets', 'NNS'), (',', ','), ('no', 'DT'), ('accidents', 'NNS'), (',', ','), ('own', 'VBP'), ('a', 'DT'), ('house', 'NN'), (',', ','), ('have', 'VBP'), ('taken', 'VBN'), ('defensive', 'JJ'), ('driving', 'VBG'), ('1', 'CD'), (',', ','), ('airbag', 'NN'), (',', ','), ('abs', 'NN'), (',', ','), ('security', 'NN'), ('alarm', 'NN'), (',', ','), ('single', 'JJ'), ('.', '.'), ('$', '$'), ('1500/year', 'CD'), ('$', '$'), ('500', 'CD'), ('decut', 'NN'), ('.', '.'), ('state', 'NN'), ('farm', 'NN'), ('insurance', 'NN'), ('(', '('), ('this', 'DT'), ('includes', 'VBZ'), ('the', 'DT'), ('additional', 'JJ'), ('$', '$'), ('100', 'CD'), ('for', 'IN'), ('the', 'DT'), ('$', '$'), ('1,000,000', 'CD'), ('umbrella', 'NN'), ('policy', 'NN'), ('over', 'IN'), ('my', 'PRP$'), ('car', 'NN'), ('and', 'CC'), ('house', 'NN'), (')', ')'), ('the', 'DT'), ('base', 'NN'), ('policy', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('standard', 'JJ'), ('$', '$'), ('100,000', 'CD'), ('-', ':'), ('$', '$'), ('100,000', 'CD'), ('-', ':'), ('$', '$'), ('300,000', 'CD'), ('policy', 'NN'), ('required', 'VBN'), ('in', 'IN'), ('de', 'NN'), ('.', '.'), ('after', 'IN'), ('2nd', 'CD'), ('defensive', 'JJ'), ('driving', 'VBG'), ('course', 'NN'), ('it', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('5', 'CD'), ('%', 'NN'), ('less', 'JJR'), ('.', '.'), ('i', 'VB'), ('bought', 'VBD'), ('the', 'DT'), ('car', 'NN'), ('in', 'IN'), ('september', 'NN'), ('1992.', 'CD'), ('the', 'DT'), ('company', 'NN'), ('i', 'NN'), ('was', 'VBD'), ('with', 'IN'), ('(', '('), ('never', 'RB'), ('had', 'VBD'), ('and', 'CC'), ('accident', 'NN'), ('or', 'CC'), ('ticket', 'NN'), ('in', 'IN'), ('11', 'CD'), ('years', 'NNS'), (')', ')'), ('quoted', 'VBD'), ('me', 'PRP'), ('$', '$'), ('2,500', 'CD'), ('.', '.'), ('hope', 'NN'), ('this', 'DT'), ('helps', 'VBZ'), ('.', '.'), ('steve', 'VB'), ('flynn', 'JJ'), ('university', 'NN'), ('of', 'IN'), ('delaware', 'NN'), ('========================================================================', '$'), ('45', 'CD'), ('kevin', 'NN'), (':', ':'), ('(', '('), ('hope', 'VBP'), ('i', 'RB'), ('remembered', 'VBN'), ('your', 'PRP$'), ('name', 'NN'), ('correctly', 'RB'), (')', ')'), ('...', ':'), ('you', 'PRP'), ('asked', 'VBD'), ('about', 'IN'), ('insurance', 'NN'), ('for', 'IN'), ('performance', 'NN'), ('cars', 'NNS'), ('.', '.'), ('well', 'RB'), (',', ','), ('last', 'JJ'), ('year', 'NN'), ('i', 'NN'), ('was', 'VBD'), ('in', 'IN'), ('a', 'DT'), ('similar', 'JJ'), ('situation', 'NN'), ('before', 'IN'), ('i', 'JJ'), ('bought', 'VBD'), ('my', 'PRP$'), ('car', 'NN ...
# [('i', 'NN'), ('would', 'MD'), ('like', 'VB'), ('to', 'TO'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('amplify', 'VB'), ('a', 'DT'), ('voltage', 'NN'), ('signal', 'NN'), ('which', 'WDT'), ('is', 'VBZ'), ('output', 'NN'), ('from', 'IN'), ('a', 'DT'), ('thermocouple', 'NN'), (',', ','), ('preferably', 'RB'), ('by', 'IN'), ('a', 'DT'), ('factor', 'NN'), ('of', 'IN'), ('100', 'CD'), ('or', 'CC'), ('1000', 'CD'), ('--', ':'), ('--', ':'), ('so', 'IN'), ('that', 'IN'), ('the', 'DT'), ('resulting', 'JJ'), ('voltage', 'NN'), ('can', 'MD'), ('be', 'VB'), ('fed', 'VBN'), ('more', 'JJR'), ('easily', 'RB'), ('into', 'IN'), ('a', 'DT'), ('personal-computer-based', 'JJ'), ('adc', 'NN'), ('data', 'NNS'), ('acquisition', 'NN'), ('card', 'NN'), ('.', '.'), ('might', 'MD'), ('anyone', 'NN'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('point', 'VB'), ('me', 'PRP'), ('to', 'TO'), ('references', 'NNS'), ('to', 'TO'), ('such', 'JJ'), ('circuits', 'NNS'), ('?', '.'), ('i', 'NNS'), ('have', 'VBP'), ('seen', 'VBN'), ('simple', 'JJ'), ('amplifier', 'JJ'), ('circuits', 'NNS'), ('before', 'IN'), (',', ','), ('but', 'CC'), ('i', 'VBP'), ('am', 'VBP'), ('not', 'RB'), ('sure', 'JJ'), ('how', 'WRB'), ('well', 'RB'), ('they', 'PRP'), ('work', 'VBP'), ('in', 'IN'), ('practice', 'NN'), ('.', '.'), ('in', 'IN'), ('this', 'DT'), ('case', 'NN'), (',', ','), ('i', 'VBP'), ("'d", 'MD'), ('like', 'VB'), ('something', 'NN'), ('which', 'WDT'), ('will', 'MD'), ('amplify', 'VB'), ('sufficiently', 'RB'), ('``', '``'), ('nicely', 'RB'), ("''", "''"), ('to', 'TO'), ('be', 'VB'), ('used', 'VBN'), ('for', 'IN'), ('thermocouples', 'NNS'), ('(', '('), ('say', 'VBP'), (',', ','), ('a', 'DT'), ('few', 'JJ'), ('degrees', 'NNS'), ('accuracy', 'VBP'), ('or', 'CC'), ('better', 'JJR'), (')', ')'), ('.', '.')]
# ...
# [('not', 'RB'), ('hard', 'RB'), (',', ','), ('you', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('the', 'DT'), ('refreshing', 'NN'), ('and', 'CC'), ('access', 'NN'), ('cycles', 'NNS'), ('by', 'IN'), ('software', 'NN'), (',', ','), ('but', 'CC'), ('this', 'DT'), ('hogs', 'VBZ'), ('most', 'JJS'), ('of', 'IN'), ('the', 'DT'), ('available', 'JJ'), ('cpu', 'NN'), ('cycles', 'NNS'), ('on', 'IN'), ('a', 'DT'), ('low-end', 'JJ'), ('controller', 'NN'), ('.', '.'), ('i', 'NN'), ("'ve", 'VBP'), ('seen', 'VBN'), ('some', 'DT'), ('application', 'NN'), ('note', 'NN'), ('from', 'IN'), ('philips', 'NNS'), ('that', 'WDT'), ('used', 'VBD'), ('one', 'CD'), ('of', 'IN'), ('their', 'PRP$'), ('8051', 'CD'), ('derivatives', 'NNS'), ('as', 'IN'), ('a', 'DT'), ('printer', 'NN'), ('buffer', 'NN'), (',', ','), ('with', 'IN'), ('up', 'IN'), ('to', 'TO'), ('1mb', 'CD'), ('of', 'IN'), ('dynamic', 'JJ'), ('ram', 'NN'), ('that', 'WDT'), ('was', 'VBD'), ('accessed', 'VBN'), ('and', 'CC'), ('refreshed', 'VBN'), ('with', 'IN'), ('software', 'NN'), ('bit-banging', 'NN'), ('.', '.'), ('another', 'DT'), ('alternative', 'NN'), ('would', 'MD'), ('be', 'VB'), ('to', 'TO'), ('use', 'VB'), ('one', 'CD'), ('of', 'IN'), ('those', 'DT'), ('nice', 'JJ'), ('dram', 'JJ'), ('controller', 'NN'), ('chips', 'NNS'), ('that', 'IN'), ('``', '``'), ('create', 'VB'), ('static', 'JJ'), ('ram', 'NN'), ('appearance', 'NN'), ("''", "''"), ('and', 'CC'), ('all', 'PDT'), ('that', 'DT'), (',', ','), ('but', 'CC'), ('they', 'PRP'), ('may', 'MD'), ('be', 'VB'), ('too', 'RB'), ('expensive', 'JJ'), ('to', 'TO'), ('make', 'VB'), ('it', 'PRP'), ('worthwhile', 'JJ'), ('.', '.')]
# [('as', 'IN'), ('the', 'DT'), ('subjects', 'NNS'), ('says', 'VBZ'), (',', ','), ('windows', 'VBZ'), ('3.1', 'CD'), ('keeps', 'NNS'), ('crashing', 'VBG'), ('(', '('), ('givinh', 'VB'), ('me', 'PRP'), ('gpf', 'JJ'), (')', ')'), ('on', 'IN'), ('me', 'PRP'), ('of', 'IN'), ('late', 'JJ'), ('.', '.'), ('it', 'PRP'), ('was', 'VBD'), ('never', 'RB'), ('a', 'DT'), ('very', 'RB'), ('stable', 'JJ'), ('package', 'NN'), (',', ','), ('but', 'CC'), ('now', 'RB'), ('it', 'PRP'), ('seems', 'VBZ'), ('to', 'TO'), ('crash', 'VB'), ('every', 'DT'), ('day', 'NN'), ('.', '.'), ('the', 'DT'), ('worst', 'JJS'), ('part', 'NN'), ('about', 'IN'), ('it', 'PRP'), ('is', 'VBZ'), ('that', 'IN'), ('it', 'PRP'), ('does', 'VBZ'), ('not', 'RB'), ('crash', 'VB'), ('consistently', 'RB'), (':', ':'), ('ie', 'NN'), ('i', 'NN'), ('ca', 'MD'), ("n't", 'RB'), ('reproduce', 'VB'), ('crashes', 'NNS'), (',', ','), ('and', 'CC'), ('they', 'PRP'), ('are', 'VBP'), ('not', 'RB'), ('always', 'RB'), ('gpf', 'VBP'), ("'s", 'VBZ'), ('in', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('application', 'NN'), ('.', '.'), ('sometimes', 'RB'), ('i', 'JJ'), ('can', 'MD'), ('recover', 'VB'), ('by', 'IN'), ('simply', 'RB'), ('closing', 'VBG'), ('the', 'DT'), ('application', 'NN'), ('that', 'WDT'), ('caused', 'VBD'), ('an', 'DT'), ('error', 'NN'), (',', ','), ('but', 'CC'), ('other', 'JJ'), ('times', 'NNS'), (',', ','), ('windows', 'NNS'), ('acts', 'VBZ'), ('very', 'RB'), ('strange', 'JJ'), (',', ','), ('and', 'CC'), ('i', 'RB'), ('need', 'VBP'), ('to', 'TO'), ('re-boot', 'NN'), ('.', '.'), ('some', 'DT'), ('background', 'NN'), (':', ':'), ('i', 'NN'), ('have', 'VBP'), ('a', 'DT'), ('leading', 'VBG'), ('edge', 'NN'), ('486sx25', 'CD'), ('with', 'IN'), ('phoenix', 'JJ'), ('bios', 'NNS'), ('.', '.'), ('when', 'WRB'), ('i', 'NN'), ('first', 'RB'), ('got', 'VBD'), ('it', 'PRP'), ('it', 'PRP'), ('had', 'VBD'), ('4mg', 'CD'), ('of', 'IN'), ('memory', 'NN'), ('.', '.'), ('it', 'PRP'), ('ran', 'VBD'), ('windows', 'NNS'), ('fine', 'NN'), ('(', '('), ('not', 'RB'), ('too', 'RB'), ('many', 'JJ'), ('gpf', 'VBP'), ("'s", 'POS'), (')', ')'), ('.', '.'), ('then', 'RB'), (',', ','), ('a', 'DT'), ('couple', 'NN'), ('of', 'IN'), ('weekends', 'NNS'), ('ago', 'IN'), (',', ','), ('i', 'NN'), ('installed', 'VBD'), ('lotus', '$'), ('123', 'CD'), ('for', 'IN'), ('windows', 'NNS'), ('(', '('), ('with', 'IN'), ('atm', 'NN'), (')', ')'), (',', ','), ('a', 'DT'), ('game', 'NN'), ('card', 'NN'), ('and', 'CC'), ('an', 'DT'), ('additional', 'JJ'), ('4', 'CD'), ('1mg', 'CD'), ('simms', 'NN'), ('.', '.'), ('the', 'DT'), ('leading', 'VBG'), ('edge', 'NN'), ('machine', 'NN'), ('is', 'VBZ'), ('kind', 'NN'), ('of', 'IN'), ('strange', 'NN'), (',', ','), ('in', 'IN'), ('that', 'DT'), ('it', 'PRP'), ('has', 'VBZ'), ('the', 'DT'), ('ide', 'NN'), ('controler', 'NN'), ('built', 'VBN'), ('into', 'IN'), ('the', 'DT'), ('motherboard', 'NN'), (',', ','), ('the', 'DT'), ('cpu', 'NN'), ('is', 'VBZ'), ('actually', 'RB'), ('on', 'IN'), ('a', 'DT'), ('sparate', 'NN'), ('board', 'NN'), ('that', 'WDT'), ('plugs', 'VBZ'), ('into', 'IN'), ('the', 'DT'), ('motherboard', 'NN'), ('and', 'CC'), ('the', 'DT'), ('simms', 'NN'), ('it', 'PRP'), ('uses', 'VBZ'), ('are', 'VBP'), ('macintosh', 'JJ'), ('simms', 'NN'), ('!', '.'), ('apparently', 'RB'), ('i', 'NN'), ('was', 'VBD'), ('told', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('leading', 'VBG'), ('edge', 'NN'), ('had', 'VBD'), ('the', 'DT'), ('parity', 'NN'), ('bit', 'NN'), ('built', 'VBN'), ('into', 'IN'), ('the', 'DT'), ('mother', 'NN'), ('board', 'NN'), ('.', '.'), ('the', 'DT'), ('original', 'JJ'), ('4mg', 'CD'), ('80ns', 'CD'), ('simms', 'NN'), ('where', 'WRB'), ('of', 'IN'), ('the', 'DT'), ('2', 'CD'), ('chip', 'NN'), ('variety', 'NN'), ('from', 'IN'), ('samsung', 'NN'), (',', ','), ('and', 'CC'), ('the', 'DT'), ('ones', 'NNS'), ('i', 'NN'), ('installed', 'VBD'), ('are', 'VBP'), ('8', 'CD'), ('chip', 'NN'), ('simms', 'NN'), ('.', '.'), ('they', 'PRP'), ('are', 'VBP'), ('recognized', 'VBN'), ('fine', 'JJ'), ...
# [('a', 'DT'), ('note', 'NN'), ('to', 'TO'), ('users', 'NNS'), ('of', 'IN'), ('plexi-fairings', 'NNS'), (':', ':'), ('if', 'IN'), ('the', 'DT'), ('light', 'NN'), ('hits', 'VBZ'), ('some', 'DT'), ('of', 'IN'), ('these', 'DT'), ('just', 'RB'), ('right', 'NN'), (',', ','), ('they', 'PRP'), ('become', 'VBP'), ('a', 'DT'), ('giant', 'JJ'), ('magnifing', 'NN'), ('glass', 'NN'), ('and', 'CC'), ('will', 'MD'), ('melt', 'VB'), ('a', 'DT'), ('hole', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('guage', 'NN'), ('pod', 'NN'), ('!', '.'), ('--', ':'), ('--', ':'), ('=====', 'JJ'), ('dod', 'NN'), ('#', '#'), ('8177', 'CD'), ('=', 'NN'), ('technician', 'JJ'), ('(', '('), ('dr.', 'JJ'), ('speed', 'NN'), (')', ')'), ('.not', 'NN'), ('.', '.'), ('student', 'NN'), ('=====', 'NN'), ('--', ':'), ('--', ':')]
# [('on', 'IN'), ('the', 'DT'), ('back', 'NN'), ('might', 'MD'), ('be', 'VB'), ('tricky', 'JJ'), (',', ','), ('but', 'CC'), ('here', 'RB'), ('in', 'IN'), ('boulder', 'NN'), (',', ','), ('there', 'EX'), ('is', 'VBZ'), ('a', 'DT'), ('guy', 'NN'), ('that', 'WDT'), ('can', 'MD'), ('always', 'RB'), ('be', 'VB'), ('seen', 'VBN'), ('with', 'IN'), ('his', 'PRP$'), ('golden', 'JJ'), ('retriever', 'NN'), ('in', 'IN'), ('the', 'DT'), ('sidecar', 'NN'), ('.', '.'), ('of', 'IN'), ('course', 'NN'), (',', ','), ('the', 'DT'), ('dog', 'NN'), ('is', 'VBZ'), ('always', 'RB'), ('wearing', 'VBG'), ('wwii', 'JJ'), ('style', 'NN'), ('goggles', 'NNS'), ('(', '('), ('no', 'DT'), ('joke', 'NN'), (')', ')')]
# [('here', 'RB'), ('is', 'VBZ'), ('a', 'DT'), ('press', 'NN'), ('release', 'NN'), ('from', 'IN'), ('the', 'DT'), ('reserve', 'NN'), ('officers', 'NNS'), ('association', 'NN'), ('.', '.'), ('reserve', 'NN'), ('officers', 'NNS'), ('say', 'VBP'), ('demographics', 'NNS'), ('ignored', 'VBN'), ('in', 'IN'), ('nominations', 'NNS'), ('to', 'TO'), ('close', 'VB'), ('naval', 'JJ'), (',', ','), ('marine', 'JJ'), ('reserve', 'NN'), ('centers', 'NNS'), ('to', 'TO'), (':', ':'), ('national', 'JJ'), ('desk', 'NN'), (',', ','), ('defense', 'NN'), ('writer', 'NN'), ('contact', 'NN'), (':', ':'), ('herbert', 'NN'), ('m.', 'JJ'), ('hart', 'NN'), ('of', 'IN'), ('the', 'DT'), ('reserve', 'NN'), ('officers', 'NNS'), ('association', 'NN'), ('of', 'IN'), ('the', 'DT'), ('united', 'JJ'), ('states', 'NNS'), (',', ','), ('202-479-2258', 'JJ'), ('washington', 'NN'), (',', ','), ('april', 'RB'), ('13', 'CD'), ('/u.s', 'NN'), ('.', '.'), ('newswire/', 'CC'), ('--', ':'), ('the', 'DT'), ('reserve', 'NN'), ('officers', 'NNS'), ('association', 'NN'), ('of', 'IN'), ('the', 'DT'), ('united', 'JJ'), ('states', 'NNS'), ('has', 'VBZ'), ('alerted', 'VBN'), ('the', 'DT'), ('defense', 'NN'), ('base', 'NN'), ('realignment', 'NN'), ('and', 'CC'), ('closure', 'NN'), ('commission', 'NN'), ('that', 'IN'), ('the', 'DT'), ('services', 'NNS'), ('failed', 'VBD'), ('to', 'TO'), ('give', 'VB'), ('sufficient', 'JJ'), ('weight', 'NN'), ('to', 'TO'), ('demographics', 'NNS'), ('in', 'IN'), ('recommendations', 'NNS'), ('made', 'VBN'), ('to', 'TO'), ('close', 'VB'), ('56', 'CD'), ('naval', 'JJ'), ('and', 'CC'), ('marine', 'JJ'), ('corps', 'NN'), ('reserve', 'NN'), ('centers', 'NNS'), ('.', '.'), ('in', 'IN'), ('letters', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('closure', 'NN'), ('commission', 'NN'), ('and', 'CC'), ('to', 'TO'), ('all', 'DT'), ('86', 'CD'), ('members', 'NNS'), ('of', 'IN'), ('congress', 'NN'), ('with', 'IN'), ('affected', 'JJ'), ('locations', 'NNS'), ('in', 'IN'), ('their', 'PRP$'), ('constituencies', 'NNS'), (',', ','), ('including', 'VBG'), ('sen.', 'JJ'), ('sam', 'NN'), ('nunn', 'NN'), ('(', '('), ('d-ga.', 'JJ'), (')', ')'), (',', ','), ('chairman', 'NN'), ('of', 'IN'), ('the', 'DT'), ('senate', 'NN'), ('armed', 'VBD'), ('services', 'NNS'), ('committee', 'NN'), (',', ','), ('roa', 'VB'), ('charged', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('developers', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('navy-marine', 'JJ'), ('list', 'NN'), ('ignored', 'VBD'), ('demographics', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('civilian', 'JJ'), ('population', 'NN'), (',', ','), ('particularly', 'RB'), ('prior', 'JJ'), ('service', 'NN'), ('personnel', 'NNS'), ('.', '.'), ('roa', 'NN'), ("'s", 'POS'), ('executive', 'NN'), ('director', 'NN'), (',', ','), ('maj.', 'FW'), ('gen.', 'FW'), ('evan', 'FW'), ('l.', 'FW'), ('hultman', 'NN'), (',', ','), ('aus', 'NN'), ('(', '('), ('ret', 'JJ'), ('.', '.'), (')', ')'), (',', ','), ('suggested', 'VBD'), ('``', '``'), ('concern', 'NN'), ('that', 'IN'), ('the', 'DT'), ('only', 'RB'), ('plausible', 'JJ'), ('alternative', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('they', 'PRP'), ('are', 'VBP'), ('intentionally', 'RB'), ('attempting', 'VBG'), ('to', 'TO'), ('foreclose', 'VB'), ('the', 'DT'), ('naval', 'JJ'), ('reserve', 'NN'), ('components', 'NNS'), ('from', 'IN'), ('maintaining', 'VBG'), ('even', 'RB'), ('today', 'NN'), ("'s", 'POS'), ('relatively', 'RB'), ('low', 'JJ'), ('level', 'NN'), ('of', 'IN'), ('participation', 'NN'), ('in', 'IN'), ('their', 'PRP$'), ('parent', 'NN'), ('service', 'NN'), ("'s", 'POS'), ('total', 'JJ'), ('force', 'NN'), ('of', 'IN'), ('the', 'DT'), ('future', 'NN'), ('.', '.'), ("''", "''"), ('he', 'PRP'), ('asked', 'VBD'), ('the', 'DT'), ('commission', 'NN'), ('``', '``'), ('to', 'TO'), ('remove', 'VB'), ('from', 'IN'), ('consideration', 'NN'), ('all', 'DT'), ('locations', 'NNS'), ('without', 'IN'), ('sufficient', 'JJ'), ('and', 'CC'), ('convincing', 'JJ'), ('demographic', 'JJ'), ('data', 'NNS'), ('to', 'TO'), ('warrant', 'VB'), ('approva ...
# [('..', 'RB'), ('deleted', 'VBN'), ('...', ':'), ('in', 'IN'), ('plain', 'NN'), ('motify', 'NN'), ('using', 'VBG'), ('a', 'DT'), ('dialog', 'NN'), ("'in-line", 'JJ'), ("'", "''"), ('like', 'IN'), ('this', 'DT'), ('simply', 'RB'), ('is', 'VBZ'), ("n't", 'RB'), ('done', 'VBN'), ('.', '.'), ('you', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('set', 'VB'), ('callbacks', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('buttons/widgets', 'NNS'), ('in', 'IN'), ('your', 'PRP$'), ('dialog', 'NN'), ('and', 'CC'), ('let', 'VB'), ('the', 'DT'), ('callback', 'NN'), ('routines', 'NNS'), ('do', 'VBP'), ('the', 'DT'), ('work', 'NN'), ('.', '.'), ('in', 'IN'), ('the', 'DT'), ('callbacks', 'NNS'), ('you', 'PRP'), ('can', 'MD'), ('then', 'RB'), ('carry', 'VB'), ('on', 'IN'), ('the', 'DT'), ('flow', 'NN'), ('of', 'IN'), ('logic', 'JJ'), ('.', '.'), ('xview', 'NN'), ('from', 'IN'), ('sun', 'NN'), ('actually', 'RB'), ('supports', 'VBZ'), ('this', 'DT'), ('very', 'RB'), ('neatly', 'RB'), ('with', 'IN'), ('a', 'DT'), ("'notify", 'NN'), ("'", "''"), ('box', 'NN'), (',', ','), ('which', 'WDT'), ('can', 'MD'), ('return', 'VB'), ('a', 'DT'), ('status', 'NN'), ('in-line', 'NN'), (',', ','), ('it', 'PRP'), ('does', 'VBZ'), ('actualy', 'JJ'), ('ease', 'VB'), ('coding', 'VBG'), ('but', 'CC'), ('goes', 'VBZ'), ('against', 'IN'), ('the', 'DT'), ('event', 'NN'), ('driven', 'JJ'), ('style', 'NN'), ('of', 'IN'), ('an', 'DT'), ('application', 'NN'), ('.', '.'), ('summary', 'JJ'), (':', ':'), ('redesign', 'NN'), ('required', 'VBN'), ('.', '.')]
# [(':', ':'), ('are', 'VBP'), ('you', 'PRP'), ('saying', 'VBG'), ('that', 'IN'), ('their', 'PRP$'), ('was', 'VBD'), ('a', 'DT'), ('physical', 'JJ'), ('adam', 'NN'), ('and', 'CC'), ('eve', 'NN'), (',', ','), ('and', 'CC'), ('that', 'IN'), ('all', 'DT'), (':', ':'), ('humans', 'NNS'), ('are', 'VBP'), ('direct', 'JJ'), ('decendents', 'NNS'), ('of', 'IN'), ('only', 'RB'), ('these', 'DT'), ('two', 'CD'), ('human', 'NN'), ('beings.', 'NN'), ('?', '.'), ('then', 'RB'), ('who', 'WP'), (':', ':'), ('were', 'VBD'), ('cain', 'NN'), ('and', 'CC'), ('able', 'JJ'), ("'s", 'POS'), ('wives', 'NNS'), ('?', '.'), ('could', 'MD'), ("n't", 'RB'), ('be', 'VB'), ('their', 'PRP$'), ('sisters', 'NNS'), (',', ','), ('because', 'IN'), ('a', 'DT'), ('&', 'CC'), ('e', 'NN'), (':', ':'), ('did', 'VBD'), ("n't", 'RB'), ('have', 'VB'), ('daughters', 'NNS'), ('.', '.'), ('were', 'VBD'), ('they', 'PRP'), ('non-humans', 'NNS'), ('?', '.'), ('genesis', 'NN'), ('5:4', 'CD'), ('and', 'CC'), ('the', 'DT'), ('days', 'NNS'), ('of', 'IN'), ('adam', 'NN'), ('after', 'IN'), ('he', 'PRP'), ('begat', 'VBD'), ('seth', 'NNS'), ('were', 'VBD'), ('eight', 'CD'), ('hundred', 'CD'), ('years', 'NNS'), (',', ','), ('and', 'CC'), ('he', 'PRP'), ('begat', 'VBD'), ('sons', 'NNS'), ('and', 'CC'), ('daughters', 'NNS'), (':', ':')]
# [(':', ':'), ('currently', 'RB'), (',', ','), ('i', 'NN'), ('use', 'VBP'), ('a', 'DT'), ('shareware', 'NN'), ('program', 'NN'), ('called', 'VBN'), ('graphics', 'NNS'), ('workshop', 'NN'), ('.', '.'), (':', ':'), ('what', 'WP'), ('kinds', 'VBZ'), ('of', 'IN'), ('things', 'NNS'), ('will', 'MD'), ('hijaak', 'VB'), ('do', 'VB'), ('that', 'IN'), ('these', 'DT'), ('shareware', 'JJ'), ('programs', 'NNS'), (':', ':'), ('will', 'MD'), ('not', 'RB'), ('do', 'VB'), ('?', '.'), ('i', 'VB'), ('also', 'RB'), ('use', 'VBP'), ('graphic', 'JJ'), ('workshop', 'NN'), ('and', 'CC'), ('the', 'DT'), ('only', 'JJ'), ('differences', 'NNS'), ('that', 'IN'), ('i', 'NN'), ('know', 'VBP'), ('of', 'IN'), ('are', 'VBP'), ('that', 'DT'), ('hijaak', 'NN'), ('has', 'VBZ'), ('screen', 'JJ'), ('capture', 'NN'), ('capabilities', 'NNS'), ('and', 'CC'), ('acn', 'NN'), ('convert', 'NN'), ('to/from', 'IN'), ('a', 'DT'), ('couple', 'NN'), ('of', 'IN'), ('more', 'JJR'), ('file', 'NN'), ('formats', 'NNS'), ('(', '('), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('specifically', 'RB'), ('which', 'WDT'), ('one', 'NN'), (')', ')'), ('.', '.'), ('in', 'IN'), ('the', 'DT'), ('april', 'NN'), ('13', 'CD'), ('issue', 'NN'), ('of', 'IN'), ('pc', 'JJ'), ('magazine', 'NN'), ('they', 'PRP'), ('test', 'VBP'), ('the', 'DT'), ('twelve', 'NN'), ('best', 'JJS'), ('selling', 'VBG'), ('image', 'NN'), ('capture/convert', 'NN'), ('utilities', 'NNS'), (',', ','), ('including', 'VBG'), ('hijaak', 'NN'), ('.', '.')]

# %%
corpus[0]
# Out:
# 'i be wonder if anyone out there could enlighten me on this car i saw the other day . it be a 2-door sport car , look to be from the late 60s/ early 70 . it be call a bricklin . the door be really small . in addition , the front bumper be separate from the rest of the body . this be all i know . if anyone can tellme a model name , engine spec , year of production , where this car be make , history , or whatever info you have on this funky look car , please e-mail .'

# %% [markdown]
# Obtenemos las bolsas de palabras de los documentos preprocesados usando la clase CountVectorizer de scikit-learn

# %%
v = CountVectorizer(stop_words='english', max_features=5000, max_df=0.8)
bolsas = v.fit_transform(corpus)

# %%
v
# Out:
# CountVectorizer(max_df=0.8, max_features=5000, stop_words='english')

# %%
print('Componentes de primer documento: {0}'.format(corpus[0]))
# Out:
# Componentes de primer documento: i be wonder if anyone out there could enlighten me on this car i saw the other day . it be a 2-door sport car , look to be from the late 60s/ early 70 . it be call a bricklin . the door be really small . in addition , the front bumper be separate from the rest of the body . this be all i know . if anyone can tellme a model name , engine spec , year of production , where this car be make , history , or whatever info you have on this funky look car , please e-mail .

# %%
print('Bolsa de primer documento: [\n{0}]'.format(bolsas[0]))
# Out:
# Bolsa de primer documento: [
#   (0, 3903)	1
#   (0, 1412)	1
#   (0, 820)	4
#   (0, 3149)	1
#   (0, 1147)	1
#   (0, 1307)	2
#   (0, 3354)	1
#   (0, 2195)	2
#   (0, 2118)	1
#   (0, 269)	1
#   (0, 1351)	1
#   (0, 281)	1
#   (0, 740)	1
#   (0, 2930)	1
#   (0, 3294)	1
#   (0, 384)	1
#   (0, 766)	1
#   (0, 3213)	1
#   (0, 3035)	1
#   (0, 708)	1
#   (0, 2095)	1
#   (0, 3538)	1
#   (0, 2369)	1
#   (0, 1407)	1
#   (0, 3338)	1
#   (0, 3945)	1
#   (0, 2829)	1
#   (0, 2243)	1
#   (0, 1820)	1
#   (0, 1944)	1
#   (0, 1643)	1
#   (0, 2234)	1]

# %% [markdown]
# Definimos la clase para el índice inverso con un método para recuperar los documentos que contienen una lista de palabras

# %%
class IndiceInverso:
    def  __getitem__(self, idx):
        return self.ifs[idx]

    def __repr__(self):
        contenido = ['%d::%s' % (i, self.ifs[i]) for i in range(len(self.ifs))]
        return "<IFS :%s >" % ('\n'.join(contenido))

    def __str__(self):
        contenido = ['%d::%s' % (i, self.ifs[i]) for i in range(len(self.ifs))]
        return '\n'.join(contenido)

    def recupera(self, l):
        return Counter([j for (i,_) in l for j in self.ifs[i]])

    def from_csr(self, csr):
        self.ifs = [[] for _ in range(csr.shape[1])]
        coo = csr.tocoo()    
        print(coo)
        for i,j,v in zip(coo.row, coo.col, coo.data):
            self.ifs[j].append(i)

# %% [markdown]
# Instanciamos nuestra clase IndiceInverso y creamos la estructura a partir de nuestras bolsas de palabras

# %%
ifs = IndiceInverso()
ifs.from_csr(bolsas)
# Out:
#   (0, 3903)	1
#   (0, 1412)	1
#   (0, 820)	4
#   (0, 3149)	1
#   (0, 1147)	1
#   (0, 1307)	2
#   (0, 3354)	1
#   (0, 2195)	2
#   (0, 2118)	1
#   (0, 269)	1
#   (0, 1351)	1
#   (0, 281)	1
#   (0, 740)	1
#   (0, 2930)	1
#   (0, 3294)	1
#   (0, 384)	1
#   (0, 766)	1
#   (0, 3213)	1
#   (0, 3035)	1
#   (0, 708)	1
#   (0, 2095)	1
#   (0, 3538)	1
#   (0, 2369)	1
#   (0, 1407)	1
#   (0, 3338)	1
#   :	:
#   (99, 3201)	1
#   (99, 1895)	1
#   (99, 1114)	1
#   (99, 814)	1
#   (99, 1714)	2
#   (99, 1922)	1
#   (99, 2831)	2
#   (99, 1616)	1
#   (99, 1071)	1
#   (99, 1250)	1
#   (99, 670)	1
#   (99, 2226)	1
#   (99, 2026)	1
#   (99, 3550)	1
#   (99, 3343)	1
#   (99, 509)	1
#   (99, 3173)	1
#   (99, 38)	1
#   (99, 3243)	2
#   (99, 3910)	2
#   (99, 2090)	1
#   (99, 1811)	3
#   (99, 819)	2
#   (99, 366)	1
#   (99, 1041)	2

# %% [markdown]
# Definimos una función que convierta de arreglos dispersos CSR a listas de listas

# %%
def csr_to_ldb(csr):
    ldb = [[] for _ in range(csr.shape[0])]
    coo = csr.tocoo()    
    for i,j,v in zip(coo.row, coo.col, coo.data):
        ldb[i].append((j, v))

    return ldb

# %% [markdown]
# Generamos algunas consultas y calculamos sus bolsas de palabras

# %%
consultas = []
for c in ['nasa space mission satellite','government crime enforcement security']:
    tokens = doc_a_tokens(c)
    consultas.append(' '.join(tokens))
# Out:
# [('nasa', 'JJ'), ('space', 'NN'), ('mission', 'NN'), ('satellite', 'NN')]
# [('government', 'NN'), ('crime', 'NN'), ('enforcement', 'NN'), ('security', 'NN')]

# %%
consultas
# Out:
# ['nasa space mission satellite', 'government crime enforcement security']

# %%
v
# Out:
# CountVectorizer(max_df=0.8, max_features=5000, stop_words='english')

# %%
bc = v.transform(consultas)
cl = csr_to_ldb(bc)

# %%
cl
# Out:
# [[(2356, 1), (2437, 1), (3142, 1), (3328, 1)],
#  [(1089, 1), (1406, 1), (1709, 1), (3193, 1)]]

# %% [markdown]
# Usamos el índice inverso para recuperar los documentos que contienen las palabras de la primera consulta ordenados por coincidencias y visualizamos el primer documento recuperado

# %%
recs = ifs.recupera(cl[0])
top = recs.most_common()[0]
recs.most_common()
# Out:
# [(59, 4), (13, 2), (67, 1), (49, 1)]

# %%
recs
# Out:
# Counter({13: 2, 59: 4, 67: 1, 49: 1})

# %%
db.data[top[0]]
# Out:
# 'Archive-name: space/new_probes\nLast-modified: $Date: 93/04/01 14:39:17 $\n\nUPCOMING PLANETARY PROBES - MISSIONS AND SCHEDULES\n\n    Information on upcoming or currently active missions not mentioned below\n    would be welcome. Sources: NASA fact sheets, Cassini Mission Design\n    team, ISAS/NASDA launch schedules, press kits.\n\n\n    ASUKA (ASTRO-D) - ISAS (Japan) X-ray astronomy satellite, launched into\n    Earth orbit on 2/20/93. Equipped with large-area wide-wavelength (1-20\n    Angstrom) X-ray telescope, X-ray CCD cameras, and imaging gas\n    scintillation proportional counters.\n\n\n    CASSINI - Saturn orbiter and Titan atmosphere probe. Cassini is a joint\n    NASA/ESA project designed to accomplish an exploration of the Saturnian\n    system with its Cassini Saturn Orbiter and Huygens Titan Probe. Cassini\n    is scheduled for launch aboard a Titan IV/Centaur in October of 1997.\n    After gravity assists of Venus, Earth and Jupiter in a VVEJGA\n    trajectory, the spacecraft will arrive at Saturn in June of 2004. Upon\n    arrival, the Cassini spacecraft performs several maneuvers to achieve an\n    orbit around Saturn. Near the end of this initial orbit, the Huygens\n    Probe separates from the Orbiter and descends through the atmosphere of\n    Titan. The Orbiter relays the Probe data to Earth for about 3 hours\n    while the Probe enters and traverses the cloudy atmosphere to the\n    surface. After the completion of the Probe mission, the Orbiter\n    continues touring the Saturnian system for three and a half years. Titan\n    synchronous orbit trajectories will allow about 35 flybys of Titan and\n    targeted flybys of Iapetus, Dione and Enceladus. The objectives of the\n    mission are threefold: conduct detailed studies of Saturn\'s atmosphere,\n    rings and magnetosphere; conduct close-up studies of Saturn\'s\n    satellites, and characterize Titan\'s atmosphere and surface.\n\n    One of the most intriguing aspects of Titan is the possibility that its\n    surface may be covered in part with lakes of liquid hydrocarbons that\n    result from photochemical processes in its upper atmosphere. These\n    hydrocarbons condense to form a global smog layer and eventually rain\n    down onto the surface. The Cassini orbiter will use onboard radar to\n    peer through Titan\'s clouds and determine if there is liquid on the\n    surface. Experiments aboard both the orbiter and the entry probe will\n    investigate the chemical processes that produce this unique atmosphere.\n\n    The Cassini mission is named for Jean Dominique Cassini (1625-1712), the\n    first director of the Paris Observatory, who discovered several of\n    Saturn\'s satellites and the major division in its rings. The Titan\n    atmospheric entry probe is named for the Dutch physicist Christiaan\n    Huygens (1629-1695), who discovered Titan and first described the true\n    nature of Saturn\'s rings.\n\n\t Key Scheduled Dates for the Cassini Mission (VVEJGA Trajectory)\n\t -------------------------------------------------------------\n\t   10/06/97 - Titan IV/Centaur Launch\n\t   04/21/98 - Venus 1 Gravity Assist\n\t   06/20/99 - Venus 2 Gravity Assist\n\t   08/16/99 - Earth Gravity Assist\n\t   12/30/00 - Jupiter Gravity Assist\n\t   06/25/04 - Saturn Arrival\n\t   01/09/05 - Titan Probe Release\n\t   01/30/05 - Titan Probe Entry\n\t   06/25/08 - End of Primary Mission\n\t    (Schedule last updated 7/22/92)\n\n\n    GALILEO - Jupiter orbiter and atmosphere probe, in transit. Has returned\n    the first resolved images of an asteroid, Gaspra, while in transit to\n    Jupiter. Efforts to unfurl the stuck High-Gain Antenna (HGA) have\n    essentially been abandoned. JPL has developed a backup plan using data\n    compression (JPEG-like for images, lossless compression for data from\n    the other instruments) which should allow the mission to achieve\n    approximately 70% of its original objectives.\n\n\t   Galileo Schedule\n\t   ------ ...

# %% [markdown]
# Repetimos el proceso anterior para la segunda consulta

# %%
recs = ifs.recupera(cl[1])
top = recs.most_common()[0]
print(recs.most_common())
print(db.data[top[0]])
# Out:
# [(70, 2), (37, 2), (71, 1), (80, 1), (55, 1), (67, 1), (76, 1), (17, 1), (38, 1)]
#
# : Pardon me? Here is to an amherst-clown:
# :
# : "Your three chiefs, Dro, Hamazasp and Kulkhandanian are the ringleaders
# :  of the bands which have destroyed Tartar villages and have staged
# :  massacres in Zangezour, Surmali, Etchmiadzin, and Zangibasar. This is
# :  intolerable.
#
#
# Were you expecting a different response? Here is another one:
#
# Source: K. S. Papazian, "Patriotism Perverted," Baikar Press, Boston, 1934,
#         (73 pages with Appendix).
#
# p. 25 (third paragraph)
#
# "Some real fighters sprang up from among the people, who struck terror
#  into the hearts of the Turks."
#
#
# "Within a few months after the war began, these Armenian guerrilla
#  forces, operating in close coordination with the Russians, were
#  savagely attacking Turkish cities, towns and villages in the east,
#  massacring their inhabitants without mercy, while at the same time
#  working to sabotage the Ottoman army's war effort by destroying roads
#  and bridges, raiding caravans, and doing whatever else they could to
#  ease Russian occupation. The atrocities committed by the Armenian
#  volunteer forces accompanying the Russian army were so severe that the
#  Russian commanders themselves were compelled to withdraw them from the
#  fighting fronts and sent them to rear guard duties. The memoirs of many
#  Russian officers who served in the east at this time are filled with
#  accounts of the revolting atrocities committed by these Armenian
#  guerrillas, which were savage even by relatively primitive standards of
#  war then observed in such areas.[1]"
#
# [1] "Journal de Guerre du Deuxieme d'Artillerie de Forteresse Russe
#      d'Erzeroum," 1919, p. 28.
#
# : >honored me by reproducing my text.  Unfortunately, he has still not produced
# : >the "documents" on "Jews in LATVIA."  Instead, he asks for my views on the
# : >"Turkish Genocide."  Well, that debate seems to be going on in a few hundred
# : >other threads.  I'll let other people bring the usual charges, try to debunk
# : >Mutlu/Argic/Cosar (a net-wide Terrorism Triangle?) and their spurious evidence.
# :
# : When that does ever happen, look out the window to see if there is a
# : non-fascist x-Soviet Armenian Government in the East. Now, where is
# : your non-existent list of scholars? What a moronian. During the First
# : World War and the ensuing years - 1914-1920, the Armenian Dictatorship
# : through a premeditated and systematic genocide, tried to complete its
# : centuries-old policy of annihilation against the Turks and Kurds by
# : savagely murdering 2.5 million Muslims and deporting the rest from
# : their 1,000 year homeland.
#
#
# How could you? Because there is none.
#
#
# Like conversing with a brick wall. And you are not responding to what I
# am writing. By the way, that "bullshit" is justly regarded as the first
# instance of Genocide in the 20th Century acted upon an entire people.
# For nearly one thousand years, the Turkish and Kurdish people lived
# on their homeland - the last one hundred under the oppressive Soviet
# and Armenian occupation. The persecutions culminated in 1914: The
# Armenian Government planned and carried out a Genocide against its
# Muslim subjects. 2.5 million Turks and Kurds were murdered and the
# remainder driven out of their homeland. After one thousand years,
# Turkish and Kurdish lands were empty of Turks and Kurds.
#
# The survivors found a safe heaven in Turkiye.
#
# Today, x-Soviet Armenian government rejects the right of Turks and
# Kurds to return to their Muslim lands occupied by x-Soviet Armenia.
#
# Today, x-Soviet Armenia covers up the genocide perpetrated by its
# predecessors and is therefore an accessory to this crime against
# humanity.
#
# x-Soviet Armenia must pay for its crime of genocide against the Muslims
# by admitting to the crime and making reparations to the Turks and Kurds.
#
#
# You may assert whatever you wish.
#
#
# Ditto.
#
# : The attempt at genocide is justly regarded as the first instance
# : of Genocide in the 20th Century acted upon an entire people.
# : This event is incontrovertibly proven by historians, government
# : and international political leaders, such as U.S. Ambassador Mark
# : Bristol, ...
#
#
# And still anxiously awaiting...
#
# : .......so the list goes on and on and on.....
# :
# : >I'm still trying to find out about those Jews in LATVIA.  Can you post those
# : >documents PLEEEEEEEASE, Mr. Argic?  Puh-leeze could you?  C'mon, it's my
# : >birthday in three weeks... post them for me as a birthday present.
# :
# : Remember, the issue at hand is the cold-blooded genocide of 2.5 million
# : Muslim people by the Armenians between 1914-1920, and the Armenian-Nazi
# : collaboration during World War II. Anything to add?
#
#
# Remember, the issue at hand is the Armenian-Nazi collaboration during
# World War II and the Turkish Genocide. And I still fail to see how
# you can challenge the following western sources.
#
# Source: John Dewey: "The New Republic," Vol. 40, Nov. 12, 1928, pp. 268-9.
#
# "Happy the minority [Jews] which has had no Christian nation to protect it.
#  And one recalls that the Jews took up their abode in 'fanatic' Turkey
#  when they were expelled from Europe, especially Spain, by Saintly Christians,
#  and they have lived here for centuries in at least as much tranquility and
#  liberty as their fellow Turkish subjects, all being exposed alike to the
#  rapacity of their common rulers. To one brought up, as most Americans have
#  been, in the Gladstonian and foreign-missionary tradition, the condition of
#  the Jews in Turkey is almost a mathematical demonstration that religious
#  differences have had an influence in the tragedy of Turkey only as they
#  were combined with aspirations for a political separation which every
#  nation in the world would have treated as treasonable. One readily
#  reaches the conclusion that the Jews in Turkey were fortunate..."
#
# He also stated that:
#
# "they [Armenians] traitorously turned Turkish cities over to the Russian
#  invader; that they boasted of having raised an army of one hundred and
#  fifty thousand men to fight a civil war, and that they burned at least
#  a hundred Turkish villages and exterminated their population."
#
# : >I want the documents of Jews in Latvia.  I think several other
# : >people on soc.culture.greek are already disputing with you about the Turkish
# : >Genocide.
# :
# : Is this the joke of the month? Who, when, how, where? What a clown...
#
#
# How about Prof Shaw, a Jewish scholar?
#
# Source: Stanford J. Shaw, on Armenian collaboration with invading Russian
# armies in 1914, "History of the Ottoman Empire and Modern Turkey (Volume
# II: Reform, Revolution & Republic: The Rise of Modern Turkey, 1808-1975)."
# (London, Cambridge University Press 1977). pp. 315-316.
#
# "In April 1915 Dashnaks from Russian Armenia organized a revolt in the city
#  of Van, whose 33,789 Armenians comprised 42.3 percent of the population,
#  closest to an Armenian majority of any city in the Empire...Leaving Erivan
#  on April 28, 1915, Armenian volunteers reached Van on May 14 and organized
#  and carried out a general slaughter of the local Muslim population during
#  the next two days while the small Ottoman garrison had to retreat to the
#  southern side of the lake."
#
# "Knowing their numbers would never justify their territorial ambitions,
#  Armenians looked to Russia and Europe for the fulfillment of their aims.
#  Armenian treachery in this regard culminated at the beginning of the First
#  World War with the decision of the revolutionary organizations to refuse
#  to serve their state, the Ottoman Empire, and to assist instead other
#  invading Russian armies. Their hope was their participation in the Russian
#  success would be rewarded with an independent Armenian state carved out of
#  Ottoman territories. Armenian political leaders, army officers, and common
#  soldiers began deserting in droves."
#
# "With the Russian invasion of eastern Anatolia in 1914 at the beginning of
#  World War I, the degree of Armenian collaboration with the Ottoman's enemy
#  increased drastically. Ottoman supply lines were cut by guerilla attacks,
#  Armenian revolutionaries armed Armenian civil populations, who in turn
#  massacred the Muslim population of the province of Van in anticipation of
#  expected arrival of the invading Russian armies."
#
# Source: Stanford J. Shaw, "History of the Ottoman Empire and Modern Turkey,"
#         Vol II. Cambridge University Press, London, 1979, pp. 314-317.
#
# "...Meanwhile, Czar Nicholas II himself came to the Caucasus to make final
#  plans for cooperation with the Armenians against the Ottomans, with the
#  president of the Armenian National Bureau in Tiflis declaring in response:
#
#  'From all countries Armenians are hurrying to enter the ranks of the
#   glorious Russian Army, with their blood to serve the victory of Russian
#   arms...Let the Russian flag wave freely over the Dardanelles and the
#   Bosporus. Let, with Your will, great Majesty, the peoples remaining
#   under the Turkish yoke receive freedom. Let the Armenian people of Turkey
#   who have suffered for the faith of Christ receive resurrection for a new
#   free life under the protection of Russia.'[155]
#
# Armenians again flooded into the czarist armies. Preparations were made
# to strike the Ottomans from the rear, and the czar returned to St. Petersburg
# confident that the day finally had come for him to reach Istanbul."
#
# [155] Horizon, Tiflis, November 30, 1914, quoted by Hovannisian, "Road to
# Independence," p. 45; FO 2485, 2484/46942, 22083.
#
# "Ottoman morale and military position in the east were seriously hurt, and
#  the way was prepared for a new Russian push into eastern Anatolia, to be
#  accompanied by an open Armenian revolt against the sultan.[156]"
#
# [156] Hovannisian, "Road to Independence," pp. 45-47; Bayur, III/1,
# pp. 349-380; W.E.D. Allen and P. Muratoff, "Caucasian Battlefields,"
# Cambridge, 1953, pp. 251-277; Ali Ihsan Sabis, "Harb Hahralaram," 2 vols.,
# Ankara, 1951, II, 41-160; FO 2146 no. 70404; FO 2485; FO 2484, nos.
# 46942 and 22083.
#
# "An Armenian state was organized at Van under Russian protection, and it
#  appeared that with the Muslim natives dead or driven away, it might be
#  able to maintain itself at one of the oldest centers of ancient Armenian
#  civilization. An Armenian legion was organized 'to expel the Turks from
#  the entire southern shore of the lake in preparation for a concerted
#  Russian drive into the Bitlis vilayet.'[162] Thousands of Armenians from
#  Mus and other major centers in the east began to flood into the new
#  Armenian state...By mid-July there were as many as 250,000 Armenians
#  crowded into the Van area, which before the crisis had housed and fed
#  no more than 50,000 people, Muslim and non-Muslim alike.[163]"
#
# [162] Hovannisian, "Road to Independence," p. 56; FOP 2488, nos. 127223 and
# 58350.
#
# [163] BVA, Meclis-i Vukela Mazbatalari, debates of August 15-17, 1915;
# Babi-i Ali Evrak Odasi, no. 175, 321, "Van Ihtilali ve Katl-i Ami,"
# Zilkade 1333/10 September 1915.
#
# :     Muslim population exterminated by the Armenians:
#
#
# Why?
#
# : Who gives a thunder about your pseudo-scholar jokes? I'am arguing about
# : the Armenian-Nazi colaboration during World War II. Any comment?
#
#
# It could be, perhaps, your head wasn't screwed on just right. In 1941,
# while the Jews were being assembled for their doom in the Nazi concentration
# camps, the Armenian volunteers in Germany formed the first Armenian
# battalion to fight alongside the Nazis. In 1943, this battalion had
# grown into eight battalions of 20,000-strong under the command of the
# former guerilla leader Dro (the butcher), who was the former dictator of the
# short-lived Armenian Dictatorship (1918-1920) and the architect of the
# cold-blooded genocide of 2.5 million Turks and Kurds between 1914-1920.
# An Armenian National Council was formed by the notorious Dashnak Party
# leaders in Berlin, which was recognized by the Nazis. Encouraged by
# this, the Armenians summarily formed a provisional government that endorsed
# and espoused fully the principles of the Nazis and declared themselves as the
# members of the Aryan super race and full participants to Hitler's policy of
# extermination of the Jews.
#
# This Armenian-Nazi conspiracy against the Jews during WWII was an "encore"
# performance staged by the Armenians during WWI, when they back-stabbed and
# exterminated 2.5 million Turks by colluding with the invading Russian army.
#
# Furthermore, as McCarthy put it, the Armenian dictatorship was granted
# a respite when the Ottomans admitted defeat and signed the Mudros
# Armistice with the Allies (October 30, 1918). The Allies had decided
# to create a Greater Armenia, including the old Russian province
# of Yerevan and adjoining areas, as well as most parts of Anatolia
# claimed by the Armenian fanatics. Only the area called Cilicia
# (around the Ottoman province of Adana) was to be excluded, as it
# had already been claimed by the French. The Allies quickly set
# about attempting to disarm Ottoman soldiers and other Turks, who
# could be expected to oppose their plans.
#
# On April 19, 1919 the British Army occupied Kars, gave civilian
# and military power over to the Armenians, then withdrew. The British
# planned for Kars to be included in the Armenian Dictatorship, even
# though the Russian pre-war census had shown Kars Province to be over
# 60% Muslim. The Turks of Kars were effectively disarmed, but the
# British could not disarm the Kurds of the mountains. The fate of
# the Turks was almost an exact replica of what had occurred earlier
# in Eastern Anatolia. Murder, pillage, genocide and the destruction
# of Turkish homes and entire Turkish villages drove the Turks of
# Kars to the mountains or south and west to the safety afforded
# by remaining units of the Ottoman Army. The British had left
# the scene to the Armenian genocide squads. Therefore, few
# Europeans were present to observe the genocide. One British
# soldier, Colonel Rawlinson, who was assigned to supervise the
# disarmament of Otoman soldiers, saw what was occurring.
#
# Rawlinson wired to his superiors,
#
# "in the interest of humanity the Armenians should not be left in
#  independent command of the Moslim population, as, their troops
#  being without discipline and not being under effective control,
#  atrocities were constantly being committed."
#
#
# Come again?
#
# : "These European Dashnags, with headquarters in Berlin, appealed to...
#
# Why?
#
# : No wonder you are in such a mess. Here are the Armenian sources on the
# : Turkish Holocaust.
#
# Why?
#
#
# Obrother. Spell it out, "list of dead Muslims":
#
# Source: Documents: Volume I (1919).
#         "Document No: 64," Archive No: 1/2, Cabin No: 109, Drawer
#         No: 4, File No: 359, Section No: 103(1435), Contents No: 3-20.
#         (To Acting Supreme Command - Socialist Salah Cimcoz, Socialist
#         Nesim Mazelyah)
#
# "Armenian gangs have been murdering and inflicting cruelties on
#  innocent people of the region. This verified information, supported
#  by clear statements of reliable eyewitnesses, was also confirmed by
#  General Odishelidje, Commander of the Russian Caucasian Army.
#
#  Armenians are entering every place evacuated by Russians carrying out
#  murders, cruelties, rape and all kind of atrocities which cannot be
#  expressed in writing, murdering all the women, children, aged people
#  who happen to be in the street. These barbarous murders repeated
#  every day with new methods continue and the Russian Army has been urged
#  to intervene to terminate these atrocities. Public opinion is appalled
#  and horrified. Newspapers are describing the happenings as shocking.
#  We have decided to inform all our friends urgently about the situation."
#
#         "Document No: 65," Archive No: 4/3671, Cabin No: 163, Drawer
#         No: 5, File No: 2947, Section No: 628, Contents No: 3-1, 3-3.
#         (To Acting Supreme Command - Commander, 3rd Army General)
#
# "The situation in the cities of Erzincan and Erzurum which we have
#  recently taken over is given below:
#
#  These two beautiful cities of our country which are alike in the
#  calamities and destruction which they suffered, have been destroyed,
#  as the specially designed and built public and private buildings of
#  these cities were deliberately burnt by Armenians apart from the
#  destruction suffered during the two-year Russian occupation.
#
#  All barracks buildings of Erzincan, the cavalry barracks in Erzurum,
#  the Government building and Army Corps Headquarters are among those
#  burnt. In short, both cities are burnt, destroyed and trees cut down.
#
#  As to the people of these cities:
#
#  All people old enough to use weapons rounded up, taken to the Sarikamis
#  direction for road building and were slaughtered. The remaining people,
#  were subject to cruelties and murder by Armenians following the
#  withdrawal of Russians and were partly annihilated the corpses thrown
#  into wells, burnt in houses, mutilated by bayonets, their abdomens
#  ripped open in slaughterhouses, their lungs and livers torn out, girls
#  and women hung up by their hair, after all kinds of devilish acts.
#  The few people who were able to survive these cruelties, worse than
#  those of the 'Spanish Inquisition,' are in poverty more dead than alive,
#  horrified, some driven insane, about 1500 in Erzincan and 30,000 in
#  Erzurum. The people are hungry and in poverty, for whatever they had
#  has been taken away from them, their lands left uncultivated.
#
#  The people have just been able to exist with some provisions found in
#  stores left over from the Russians. The villages round Erzincan and
#  Erzurum are in the worst condition. Some villages on the road, have
#  been leveled to the ground, leaving no stone, the people completely
#  massacred.
#
#  Let me submit to your information with deep grief and regret that
#  history has never before witnessed cruelties at such dimensions."
#
# :  (a long list)
# :  (a long list)"
#
# And still anxiously awaiting...
#
# Serdar Argic

# %% [markdown]
# #### Búsqueda de documentos similares

# %% [markdown]
# Ahora vamos a realizar búsquedas de documentos similares a un documento de consulta.
#
# Primero tomamos 1 documento que sirva de consulta y lo visualizamos

# %%
dc = db.data[0]
dc
# Out:
# 'I was wondering if anyone out there could enlighten me on this car I saw\nthe other day. It was a 2-door sports car, looked to be from the late 60s/\nearly 70s. It was called a Bricklin. The doors were really small. In addition,\nthe front bumper was separate from the rest of the body. This is \nall I know. If anyone can tellme a model name, engine specs, years\nof production, where this car is made, history, or whatever info you\nhave on this funky looking car, please e-mail.'

# %% [markdown]
# Obtenemos su bolsa

# %%
tokens = doc_a_tokens(dc)
bolsa_dc = v.transform([' '.join(tokens)])
print('Componentes para consulta: {0}'.format(tokens))
print('Bolsa para consulta: [\n{0}]'.format(bolsa_dc))
# Out:
# [('i', 'NN'), ('was', 'VBD'), ('wondering', 'VBG'), ('if', 'IN'), ('anyone', 'NN'), ('out', 'IN'), ('there', 'RB'), ('could', 'MD'), ('enlighten', 'VB'), ('me', 'PRP'), ('on', 'IN'), ('this', 'DT'), ('car', 'NN'), ('i', 'NN'), ('saw', 'VBD'), ('the', 'DT'), ('other', 'JJ'), ('day', 'NN'), ('.', '.'), ('it', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('2-door', 'JJ'), ('sports', 'NNS'), ('car', 'NN'), (',', ','), ('looked', 'VBD'), ('to', 'TO'), ('be', 'VB'), ('from', 'IN'), ('the', 'DT'), ('late', 'JJ'), ('60s/', 'CD'), ('early', 'JJ'), ('70s', 'CD'), ('.', '.'), ('it', 'PRP'), ('was', 'VBD'), ('called', 'VBN'), ('a', 'DT'), ('bricklin', 'NN'), ('.', '.'), ('the', 'DT'), ('doors', 'NNS'), ('were', 'VBD'), ('really', 'RB'), ('small', 'JJ'), ('.', '.'), ('in', 'IN'), ('addition', 'NN'), (',', ','), ('the', 'DT'), ('front', 'NN'), ('bumper', 'NN'), ('was', 'VBD'), ('separate', 'JJ'), ('from', 'IN'), ('the', 'DT'), ('rest', 'NN'), ('of', 'IN'), ('the', 'DT'), ('body', 'NN'), ('.', '.'), ('this', 'DT'), ('is', 'VBZ'), ('all', 'DT'), ('i', 'NN'), ('know', 'VBP'), ('.', '.'), ('if', 'IN'), ('anyone', 'NN'), ('can', 'MD'), ('tellme', 'VB'), ('a', 'DT'), ('model', 'NN'), ('name', 'NN'), (',', ','), ('engine', 'NN'), ('specs', 'NN'), (',', ','), ('years', 'NNS'), ('of', 'IN'), ('production', 'NN'), (',', ','), ('where', 'WRB'), ('this', 'DT'), ('car', 'NN'), ('is', 'VBZ'), ('made', 'VBN'), (',', ','), ('history', 'NN'), (',', ','), ('or', 'CC'), ('whatever', 'WDT'), ('info', 'VBP'), ('you', 'PRP'), ('have', 'VBP'), ('on', 'IN'), ('this', 'DT'), ('funky', 'NN'), ('looking', 'VBG'), ('car', 'NN'), (',', ','), ('please', 'VB'), ('e-mail', 'JJ'), ('.', '.')]
# Componentes para consulta: ['i', 'be', 'wonder', 'if', 'anyone', 'out', 'there', 'could', 'enlighten', 'me', 'on', 'this', 'car', 'i', 'saw', 'the', 'other', 'day', '.', 'it', 'be', 'a', '2-door', 'sport', 'car', ',', 'look', 'to', 'be', 'from', 'the', 'late', '60s/', 'early', '70', '.', 'it', 'be', 'call', 'a', 'bricklin', '.', 'the', 'door', 'be', 'really', 'small', '.', 'in', 'addition', ',', 'the', 'front', 'bumper', 'be', 'separate', 'from', 'the', 'rest', 'of', 'the', 'body', '.', 'this', 'be', 'all', 'i', 'know', '.', 'if', 'anyone', 'can', 'tellme', 'a', 'model', 'name', ',', 'engine', 'spec', ',', 'year', 'of', 'production', ',', 'where', 'this', 'car', 'be', 'make', ',', 'history', ',', 'or', 'whatever', 'info', 'you', 'have', 'on', 'this', 'funky', 'look', 'car', ',', 'please', 'e-mail', '.']
# Bolsa para consulta: [
#   (0, 269)	1
#   (0, 281)	1
#   (0, 384)	1
#   (0, 708)	1
#   (0, 740)	1
#   (0, 766)	1
#   (0, 820)	4
#   (0, 1147)	1
#   (0, 1307)	2
#   (0, 1351)	1
#   (0, 1407)	1
#   (0, 1412)	1
#   (0, 1643)	1
#   (0, 1820)	1
#   (0, 1944)	1
#   (0, 2095)	1
#   (0, 2118)	1
#   (0, 2195)	2
#   (0, 2234)	1
#   (0, 2243)	1
#   (0, 2369)	1
#   (0, 2829)	1
#   (0, 2930)	1
#   (0, 3035)	1
#   (0, 3149)	1
#   (0, 3213)	1
#   (0, 3294)	1
#   (0, 3338)	1
#   (0, 3354)	1
#   (0, 3538)	1
#   (0, 3903)	1
#   (0, 3945)	1]

# %% [markdown]
# Definimos una función para hacer búsqueda por fuerza bruta dada una función de distancia o similitud

# %%
def fuerza_bruta(base, consulta, fd):
    medidas = np.zeros(base.shape[0])
    for i,x in enumerate(base):
        medidas[i] = fd(consulta, x)

    return medidas

# %% [markdown]
# Definimos la función para la similitud coseno

# %%
def similitud_coseno(x, y):
    x = x.toarray()[0]
    y = y.toarray()[0]
    pnorma = (np.sqrt(x @ x) * np.sqrt(y @ y))

    if pnorma > 0:
        return (x @ y) / pnorma
    else: 
        return np.nan

# %%
bolsa_dc
# Out:
# <1x3970 sparse matrix of type '<class 'numpy.int64'>'
# 	with 32 stored elements in Compressed Sparse Row format>

# %%
sims = fuerza_bruta(bolsas[1:], bolsa_dc, similitud_coseno)

# %%
print('Similitud máxima es {0} de documento {1}'.format(np.nanmax(sims), np.nanargmax(sims)+ 1))
# Out:
# Similitud máxima es 0.2527318481572156 de documento 17

# %% [markdown]
# Revisamos documento más similar

# %%
print(db.data[np.nanargmax(sims) + 1])
# Out:
# I recently posted an article asking what kind of rates single, male
# drivers under 25 yrs old were paying on performance cars. Here's a summary of
# the replies I received.
#
#
#
#
# -------------------------------------------------------------------------------
#
# I'm not under 25 anymore (but is 27 close enough).
#
# 1992 Dodge Stealth RT/Twin Turbo (300hp model).
# No tickets, no accidents, own a house, have taken defensive driving 1,
# airbag, abs, security alarm, single.
#
# $1500/year  $500 decut. State Farm Insurance (this includes the additional $100
# for the $1,000,000 umbrella policy over my car and house)  The base
# policy is the standard $100,000 - $100,000 - $300,000 policy required in DE.
#
# After 2nd defensive driving course it will be 5% less.
#
# I bought the car in September 1992.  The company I was with (never had
# and accident or ticket in 11 years) quoted me $2,500.
#
# Hope this helps.
#
# Steve Flynn
# University of Delaware
# ======================================================================== 45
#
#     Kevin:
#
#     (Hope I remembered your name correctly)...
#
#     You asked about insurance for performance cars.  Well, last year
#     I was in a similar situation before I bought my car, and made the
#     same inquiry as you.
#
#     Age: 24 (then and now)
#     Car: 1992 Eagle Talon TSi AWD
#     Driving Record: Clean
#     State: Illinois
#     Cost: $820/6 mos.
#
#     I turn 25 in May and the insurance goes down to $520/6 mos.
#     Also, I'm single and that incurs a higher rate with my company.
#
#     I've got a couple other friends w/ AWDs and they pay more
#     than I do (different ins. companies also), so maybe I'm just lucky.
#
#     Hope the info helps.
#
#     Dan
#     [dans@jdc.gss.mot.com]
#     Motorola Cellular Subscriber Group
#
# ======================================================================== 38
#  USA
# Cc:
#
# I'm 23; live in Norman, Oklahoma; drive an '89 Thunderbird SC; have
# never made a claim against my insurance (though I have been hit
# several times by negligent drivers who couldn't see stop signs or
# were fiddling with their radios); and I have had three moving violations
# in the last 18 months (one for going 85 in a 55; one for "failure to
# clear an intersection" (I still say the damn light was yellow); and
# one for going 35 in a 25 (which didn't go on my record)). My rates
# from State Farm (with a passive restraint deduction) on liability,
# $500 deductible comprehensive, and $500 deductible collision are
# roughly $1300/year. (I was paying just over $1100/year for a '92 Escort LX.)
#
# 				James
#
# James P. Callison    Microcomputer Coordinator, U of Oklahoma Law Center
# Callison@uokmax.ecn.uoknor.edu   /\    Callison@aardvark.ucs.uoknor.edu
# DISCLAIMER: I'm not an engineer, but I play one at work...
# 		The forecast calls for Thunder...'89 T-Bird SC
#    "It's a hell of a thing, killing a man. You take away all he has
# 	and all he's ever gonna have."
# 			--Will Munny, "Unforgiven"
# ======================================================================== 61
#
# I am beyond the "under 25" age group, but I have an experience a few
# years ago that might be interesting to you.  I owned a 1985 Toyota Celica
# GT.  I decided to buy myself a gift - a more exotic car.  Front runners
# included the Toyota Supra Turbo and the Porsche 924 (1987 model years).
# I narrowed it down to those two.  I liked the simplicity and handling
# (and snob appeal, too) of driving a Porsche.  The Supra Turbo was less
# money and had more features and performance - almost a personal luxury
# car.  It had better acceleration and a higher top speed than the 924.
# I was almost ready to give in to a buying impulse for the 924, but i
# decided to stop by my insurance agent's office on the way.  I asked
# about what would happen to my rate with either car.
#
# "If you buy the Supra, your rate classification will be the same as
# the Celica (the '85 Celica was considered a subcompact and for that
# year was rated as one of the safest cars), with a slight increase because
# the car will be 2 years newer.  Our lower-risk division will continue
# to handle your account.
#
# "If you buy the Porsche 924, we'll have to change you to the standard
# [higher] rate company and your rate will double.  And if you go with
# a 944, it's another story again - we'll cover the rest of this year,
# but cancel you after that."
#
# "But the Supra is much faster than the 924, and the 924 is actually
# faster than the [standard] 944.  That doens't make sense."
#
#  That's what the book says.  We don't insure Corvettes, either.  For
# some reason, the underwriters consider Supras - and their drivers -
# as very traditional and conservative."
#
# I eventually went with the Supra for a number of reasons.  The Porsche
# dealer had a nice salesman to get me interested, but a tough high-pressure
# guy in the back room.  At equal monthly payments, it would have taken
# a year longer to pay for the Porsche, plus its higher insurance.  I
# concluded that the high insurance was related to probability of auto
# theft.
#
#    /|/| /||)|/  /~ /\| |\|)[~|)/~   |   Everyone's entitled to MY opinion.
#   / | |/ ||\|\  \_|\/|_|/|)[_|\\_|  |      goldberg@oasys.dt.navy.mil
# ========Imagination is more important than knowledge. - Albert Einstein=======
#
#
#
#
#
# ======================================================================== 32
#
# I live in Idaho.  When I was <26 many years ago (10 years) I bought a Trans
# Am (new).  Insurance was about $1300/year.  When I turned 26, it immediately
# dropped to $460/year.  I had not had any accidents before or after, this was
# strictly an age change.  That same rate stayed pretty much the same until I
# sold the car 2 years ago.  My F-150 pickup is about $80/year less.
#
# The real amazing thing is that when I woke up at age 25, I felt SO MUCH MORE
# RESPONSIBLE than I was before...  :-)
#
# Wes
#
# ======================================================================== 21
#
#
# For your information:
# California
# Male, single, under 25 , No moving violation
# Alfa Spider
#      =======> $2000 / year
#
# What a bargain!!!
# ======================================================================== 28
#
# Let's see, I'm 24, single, male, clean driving record. I have a 92 VW COrrado
# VR6. I live in San Jose, California. I pay ~1500$ a year through Allstate. A
# good deal if you ask me.
#
# I was thinking about getting a Talon, but I think the insurance is higher
# for a "turbo" sports car vs a V6
#
# -W
#
# ======================================================================== 27
#
# 1986 Honda CRX Si, clean record, in a small New Mexico town was around $800
# per year, age 24.
#
# Nearby city rates were 1.5X-2X higher than where I've got mine insured.
#
# ..robert
# --
# Robert Stack / Institute of Transportation Studies, Univ of California-Irvine
#                stack@translab.its.uci.edu   '92 Mazda Protege LX
# ======================================================================== 37
# 1300 per year, 1992 Saturn SC, 21 Years old, State: New Mexico,
# Insurance: State Farm.
#
#
# ======================================================================== 64
#
#
# Here is my info:
#
# Car             : '89 Toyota Celica ST
# Insurance Co    : Farmer's Insurance
# Yearly insurance: $2028
# Age             : 24
# Date of license : Oct 14, 1992
# Residence       : Mountain View, California
# No moving violations (for now atleast ;-)
#
# Hope this helps. Please post a summary if possible.
#
# Vijay
# **********************************************************************
# Vijay Anisetti
# Email: anisetti@informix.com   Apt: (415)962-0320   Off: (415)926-6547
# ======================================================================== 38
# Single, 24 years old, Eagle Talon Turbo AWD, $1200 (full-cover, reasonable
#  liability)
# No tickets, No violations, No accidents... (knock on wood...)
# Mass,
#
# 	One thing that makes a HUGE difference in MASS is the town you live in.
# I'm personally in one of the best towns within reasonable distance
# of Boston.  If I moved to the absolute best it would go down to about
# $1150, if I moved to the worst it would be $2000+..
#
# 	Also one accident and a couple of tickets, would probably add another $600...
#
#
# 	_RV
#
#
# ======================================================================== 43
# I have a 1990 Mitsubishi eclipse turbo awd, am 23 years old and have no
# tickets that went on my record.  I live in Illinois just outside of Chicago
# and pay $1560 a year with full coverage at State Farm.  I did get a small
# discount because of my alarm system($30 a year).  I only live 15 miles from
# Chicago but if I actually lived in the city the price would be about $2000
# a year.
# ======================================================================== 41
# I'm over 25, but in case you're interested anyway, I'm insuring a 93 SHO
# for $287/6 month.  Thats 100k personal+300k total+100k property with
# 250 deductible, glass and towing, State Farm.
#
# ======================================================================== 39
#
# Unless you are under 20 or have been driving for less than 5
# years, I think you are being seriously ripped off.  I don't have
# one of the performance cars you listed, but if your record is
# clean, then you should not be paying over $2K.
#
# Did you try calling all the insurance dealers you could find?
# Although rates are supposed to be standardized, I've found that
# most places I initially call, give me some ridiculously high
# quote and *finaly*, I hit one that is much lower.
#
# Also, I have changed insurance companies when the rate went up at
# renewal (no accidents, tickets, car gets older??) to maintain a low
# rate.  You always have to be careful when it comes to insurance
# companies 8^).

# %% [markdown]
# Definimos la distancia euclidiana

# %%
def distancia_euclidiana(x, y):   
    x = x.toarray()[0]
    y = y.toarray()[0]
    return np.sqrt(np.sum((x - y)**2))

# %% [markdown]
# Repetimos el proceso anterior con la distancia euclidiana

# %%
euclids = fuerza_bruta(bolsas[1:], bolsa_dc, distancia_euclidiana)
print('Distancia mínima es {0} de documento {1}'.format(np.nanmin(euclids), np.nanargmin(euclids) + 1))
# Out:
# Distancia mínima es 7.280109889280518 de documento 12

# %% [markdown]
# Visualizamos el documento

# %%
print(db.data[np.nanargmin(euclids) + 1])
# Out:
# --
